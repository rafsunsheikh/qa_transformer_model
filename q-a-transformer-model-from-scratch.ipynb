# %% [markdown]
# <a href="https://www.kaggle.com/code/rafsunsheikh/q-a-transformer-model-from-scratch?scriptVersionId=140018350" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# Load the required Libraries
import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import math
import copy
import json
from transformers import BertTokenizer
from sklearn.model_selection import train_test_split

# %% [markdown]
# **If you want to use GPU**

# %%
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# print("Device:", device)

# %% [markdown]
# ### **Load the Dataset**

# %%
# Load the JSON dataset
with open("/kaggle/input/qa-dataset/qa_dataset.json", "r") as f:
    qa_data = json.load(f)

# %% [markdown]
# ### **Split the dataset into question, context and answer**

# %%
# Extract questions, contexts, and answers
questions = [qa["question"] for qa in qa_data]
contexts = [qa["context"] for qa in qa_data]
answers = [qa["answer"] for qa in qa_data]

# %% [markdown]
# # **Split the Dataset into train, test and Validation**

# %%
# Split the dataset into train, test, and validation sets
train_questions, test_questions, train_contexts, test_contexts, train_answers, test_answers = train_test_split(
    questions, contexts, answers, test_size=0.2, random_state=42
)
train_questions, val_questions, train_contexts, val_contexts, train_answers, val_answers = train_test_split(
    train_questions, train_contexts, train_answers, test_size=0.2, random_state=42
)

# Print the sizes of the datasets
print("Train dataset size:", len(train_questions))
print("Validation dataset size:", len(val_questions))
print("Test dataset size:", len(test_questions))
# Out:
# Train dataset size: 137
# Validation dataset size: 35
# Test dataset size: 43

# %%
questions
# Out:
# ['What is a modem?',
#  'What is the purpose of a router?',
#  "What does 'bandwidth' refer to in telecommunication?",
#  'Explain the concept of latency in telecommunication.',
#  'What is VoIP?',
#  'Describe the role of a network firewall.',
#  'What is the difference between 4G and 5G?',
#  'What is a fiber optic cable?',
#  'How does Wi-Fi work?',
#  'What is latency in online gaming?',
#  'What is a satellite communication system?',
#  'Explain the concept of VoLTE.',
#  'What is a modem?',
#  'What is latency in telecommunication?',
#  'Explain the concept of bandwidth throttling.',
#  'What is the OSI model?',
#  'What is fiber-to-the-home (FTTH) technology?',
#  'What are the benefits of using SIP in telephony?',
#  'How does a wireless router work?',
#  'What is a DNS server and what role does it play in networking?',
#  'Explain the difference between 4G and 5G networks.',
#  'What is a VPN and why is it used in telecommunications?',
#  'Describe the role of a network switch in data communication.',
#  'What is VoLTE and how does it differ from traditional voice calls?',
#  'What is telecommunication?',
#  'What are the basic components of a modern digital telecommunications system?',
#  'Why is digital transmission preferred over analog transmission?',
#  'What is the process of analog-to-digital conversion?',
#  'What is source encoding in a digital telecommunications system?',
#  'What is channel encoding in a digital telecommunications system?',
#  'What is the role of modulation in telecommunications?',
#  'What is multiplexing in telecommunications?',
#  'What happens during the reverse process of transmission at the receiving end?',
#  'What are the components of a digital telecommunications system outlined in the article?',
#  'What is analog-to-digital conversion?',
#  'What are the basic steps in analog-to-digital conversion?',
#  'What is the significance of the binary signal in telecommunication?',
#  'Why is analog-to-digital conversion necessary for analog signals?',
#  'What is sampling in analog-to-digital conversion?',
#  'Explain the process of quantization in analog-to-digital conversion.',
#  'What is the role of quantization levels in analog-to-digital conversion?',
#  'How does the encoding of quantized values into binary digits work?',
#  'What is the importance of the Huffman code in source encoding?',
#  'How does the Lempel-Ziv algorithm improve compression efficiency?',
#  'What is the purpose of the channel encoder in telecommunication?',
#  'What are the two main methods for protecting transmitted information from errors?',
#  'Explain the concept of forward error control (FEC) in error protection.',
#  'How does the automatic repeat request (ARQ) method protect against errors?',
#  'What is a repetition code and how does it work?',
#  'Explain the Hamming code as an FEC method.',
#  'How does convolutional encoding differ from block coding?',
#  'What is the purpose of memory in convolutional encoding?',
#  'How does trellis coding differ from convolutional encoding?',
#  'What is modulation in telecommunications?',
#  'Why is modulation necessary in telecommunications?',
#  'Explain the concept of amplitude modulation (AM) and its purpose.',
#  'What is frequency modulation (FM) and why is it used?',
#  'How is digital modulation used to transmit computer data?',
#  'What is amplitude-shift keying (ASK) and how does it work?',
#  'Explain frequency-shift keying (FSK) in digital modulation.',
#  'What is phase-shift keying (PSK) and how does it function?',
#  'What is the purpose of multiplexing in telecommunications?',
#  'Explain frequency-division multiplexing (FDM) and its application.',
#  'What is the principle behind time-division multiplexing (TDM)?',
#  'Can time-division multiplexing (TDM) be used for analog signals?',
#  'Describe the process of combining signals in frequency-division multiplexing (FDM).',
#  'How does time-division multiplexing (TDM) ensure data separation?',
#  'What are the three schemes used for efficient sharing of a single channel in telecommunications?',
#  'Explain the concept of frequency-division multiple access (FDMA) and its application.',
#  'Describe the time-division multiple access (TDMA) method and its challenges.',
#  'What is code-division multiple access (CDMA), and how does it work?',
#  'What distinguishes CDMA from other multiple access methods?',
#  'What is the origin of telecommunication and its purpose?',
#  'How has the transmission media in telecommunication evolved?',
#  'What are some examples of pre-modern long-distance communication methods?',
#  'Who were some of the pioneering inventors and developers in the field of electrical and electronic telecommunications?',
#  'How has the proliferation of digital technologies impacted telecommunication?',
#  "What is the etymology of the term 'telecommunication'?",
#  'What organizations merged to form the International Telecommunication Union (ITU)?',
#  'How was telecommunication defined by the International Telecommunication Union (ITU)?',
#  'What historical cultures and civilizations used homing pigeons for communication?',
#  'What was the purpose of chains of beacons used on hilltops in the Middle Ages?',
#  'Who is credited with building the first fixed visual telegraphy system, and what was its name?',
#  'Who demonstrated the first commercial electrical telegraph, and when was it demonstrated?',
#  'What important advance did Samuel Morse make in his version of the electrical telegraph?',
#  'When was the first transatlantic telegraph cable successfully completed, and what significance did it have?',
#  'Who patented the conventional telephone, and when was the patent approved?',
#  'Who invented a device for the electrical transmission of voice before the telephone, and why was it of limited practical value?',
#  'When and where were the first commercial telephone services set up by the Bell Telephone Company?',
#  'Who began developing wireless communication using radio waves, and when did they show that radio waves could be transmitted across the Atlantic Ocean?',
#  'When did the first radio message cross the Atlantic from North America, and which station transmitted it?',
#  'When did commercial radio AM broadcasting begin, and what role did it play?',
#  'When did the development of stereo FM broadcasting of radio start, and what did it replace as the dominant commercial standard?',
#  'When and where did John Logie Baird demonstrate the transmission of moving pictures, and what was the basis of his television device?',
#  'Who produced the first version of a television to show promise, and when was it demonstrated?',
#  'When did television become an important home entertainment broadcast medium, and what technology played a significant role in its development?',
#  'What fundamental electronic functions does a thermionic tube or valve perform?',
#  'Who invented the diode, the simplest vacuum tube, and what components does it consist of?',
#  'What role do control grids play in a thermionic tube, and how do they affect the current between the cathode and anode?',
#  'What were the key applications of thermionic tubes in electronic circuits during the 20th century?',
#  'What advancements led to the replacement of thermionic tubes, and what technology replaced them?',
#  'When did George Stibitz demonstrate remote computing using a teletype, and what configuration did he use?',
#  'Who started to investigate packet switching technology, and what technology emerged from their work?',
#  'How did the effective capacity to exchange information worldwide through two-way telecommunication networks grow from 1986 to 2007?',
#  'What does the growth of transmission capacity from 1986 to 2007 equate to in terms of newspaper pages per person per day?',
#  'What role do telecommunications play in the world economy, and how big was the global telecommunications industry in 2012?',
#  "What was the service revenue of the global telecommunications industry estimated to be in 2010, and what percentage of the world's gross domestic product (GDP) does it correspond to?",
#  'What are the basic elements of a telecommunication system?',
#  'In a radio broadcasting station, what is the transmitter and what is the interface between the power amplifier and the free space channel?',
#  'What is the role of a transceiver in telecommunication?',
#  'Why do transceivers need to be carefully designed and built?',
#  "What is meant by 'point-to-point communication' and 'broadcast communication'?",
#  'What are multiplex systems in telecommunication and what advantage do they offer?',
#  'What are the two ways in which communication signals can be sent?',
#  'How do analog signals vary with respect to information?',
#  'What is the key advantage of digital signals over analog signals?',
#  'What happens to analog systems as noise increases?',
#  'How do digital systems react to noise that exceeds their ability to autocorrect?',
#  'What is the downside of digital transmission of continuous data?',
#  "What are the two different meanings of the term 'channel' in telecommunications?",
#  'Give examples of physical mediums that serve as communication channels.',
#  'What is the concept of frequency-division multiplexing (FDM)?',
#  'What is the alternative method of dividing a communications medium into channels?',
#  'What are the characteristics of communication systems that use a hybrid of TDM and FDM?',
#  'What is modulation, and how is it used to convey information?',
#  'What is phase-shift keying (PSK) and how is it used in communication systems?',
#  'How does modulation enable the transmission of low-frequency analog signals?',
#  'What advantage does modulation offer in terms of frequency division multiplexing (FDM)?',
#  'What is a telecommunications network?',
#  'What is the role of routers in digital communications networks?',
#  'What components make up an analog communications network?',
#  'Why might repeaters be necessary in telecommunications networks?',
#  'What advantage do digital systems have over analog systems?',
#  'What are some examples of how telecommunication has impacted microeconomics?',
#  'What macroeconomic link has been suggested between telecommunication infrastructure and economic growth?',
#  "What is the 'digital divide' in relation to telecommunication?",
#  'How has telecommunication impacted social relationships?',
#  'What role have social networking sites played in social interactions?',
#  "How has telecommunication impacted the public's access to music and film?",
#  'How has telecommunication transformed the way people receive news?',
#  'What impact has telecommunication had on advertising expenditures?',
#  'What are the International Telecommunication Regulations established by the International Telecommunication Union (ITU)?',
#  'What is the digital divide in the context of telecommunication access?',
#  'How has telecommunication impacted advertising expenditures?',
#  'What are some key trends in the sales of telecommunication equipment over the years?',
#  'How do telephone networks work in terms of connections and signals?',
#  'What is the main advantage of digital broadcasts over traditional analog broadcasts?',
#  'What are the three competing standards for digital television broadcasting?',
#  'What is the key difference between HD Radio and Eureka 147 for digital audio broadcasting?',
#  'When did the United States end analog television transmission?',
#  'What are the three standards for broadcasting color TV in analog television?',
#  'What is the OSI reference model?',
#  'What is the purpose of protocols in computer networks?',
#  'What are the characteristics that distinguish local area networks (LANs) from larger networks?',
#  'What are some of the advantages of wide area networks (WANs)?',
#  'What were some of the communication protocols that emerged in the mid-1980s to fill gaps between data-link and application layers?',
#  'What technologies replaced existing local area network technologies as the Internet grew in popularity?',
#  'What are the typical data-link protocols for larger networks like WANs and for LANs?',
#  'What is the distinction between multimode fibers and single-mode fibers in networking?',
#  'What is a telecommunications network?',
#  'What are the different planes in a telecommunications network?',
#  'What are some examples of telecommunications networks?',
#  'What are the features that differentiate Metropolitan Area Networks (MANs) from LANs or WANs?',
#  "What is the trend described by Edholm's law in telecommunication networks?",
#  'What is a computer network?',
#  'What are the nodes of a computer network?',
#  'What historical milestones influenced the development of computer networking?',
#  'What technologies are used to extend interpersonal communications in computer networks?',
#  'What is a network packet in computer networks?',
#  'How does the topology of a network affect its throughput and reliability?',
#  'What are some common network topologies?',
#  'What is an overlay network and how does it differ from the underlying network?',
#  'What are some examples of transmission media used in computer networking?',
#  'What are some examples of wired technologies used in computer networking?',
#  'How are wireless network connections established?',
#  'What is a network interface controller (NIC) and what is its function?',
#  'What is the purpose of a repeater in networking?',
#  'How do bridges and switches differ from hubs in networking?',
#  'What is the role of routers in networking?',
#  'How are modems used in networking?',
#  'What is the function of a firewall in networking?',
#  'What is a communication protocol?',
#  'How are communication protocols organized in a protocol stack?',
#  'What is the significance of the TCP/IP model?',
#  'What does the IEEE 802 protocol suite encompass?',
#  'What is the main technology behind Ethernet networks?',
#  'What is the IEEE 802.11 standard used for?',
#  'What are SONET and SDH protocols used for?',
#  'What is Asynchronous Transfer Mode (ATM) and how does it differ from other protocols?',
#  'What is the role of cellular standards like GSM and CDMA in networking?',
#  'What is routing in computer networks?',
#  'How are routing protocols used in packet-switched networks?',
#  'What are some examples of network devices involved in routing?',
#  'How do routing tables contribute to the routing process?',
#  'What is the difference between routing and bridging?',
#  'What is the role of a home area network (HAN)?',
#  'What is the purpose of a storage area network (SAN)?',
#  'What is a backbone network and what does it connect?',
#  'What is a wide area network (WAN) and how does it function?',
#  'What is the Internet and what technologies underlie its functioning?',
#  'What are network services in computer networks?',
#  'Can you give examples of well-known network services?',
#  "What does the term 'bandwidth' refer to in computing?",
#  'What is network delay in telecommunications?',
#  'What is quality of service (QoS) in network performance?',
#  'What is network congestion and how does it affect networks?',
#  'What is network resilience and why is it important?',
#  'What is network security and why is it important?',
#  'What is end-to-end encryption and why is it used?',
#  'What is SSL/TLS and how does it enhance network security?',
#  'What are the different views of networks from users and network administrators?',
#  'How do network administrators view networks from physical and logical perspectives?',
#  'What is the difference between an intranet and an extranet?',
#  'What constitutes the Internet from an engineering viewpoint?',
#  'What types of communications are common over the Internet?']

# %%
contexts
# Out:
# ['A modem is a device that modulates and demodulates digital data to allow communication between computers over telephone lines.',
#  'A router is used to direct data packets between different computer networks. It helps manage the flow of data and ensure efficient communication.',
#  'Bandwidth refers to the maximum data transfer rate of a network connection. It measures how much data can be transmitted in a given time period.',
#  'Latency is the delay between sending and receiving data in a network. It can impact real-time communication and online gaming experiences.',
#  'VoIP stands for Voice over Internet Protocol. It is a technology that allows voice communication and multimedia sessions over the Internet, enabling phone calls through data networks.',
#  'A network firewall is a security device that monitors and controls incoming and outgoing network traffic. It acts as a barrier between a trusted internal network and untrusted external networks.',
#  'The main difference between 4G and 5G is the speed and latency. 5G offers significantly faster data transfer rates and lower latency compared to 4G. This enables new applications such as augmented reality and remote surgery.',
#  'A fiber optic cable is a type of high-speed transmission medium made of glass or plastic fibers. It uses light signals to transmit data over long distances with minimal signal loss and electromagnetic interference.',
#  'Wi-Fi, short for Wireless Fidelity, works by transmitting data using radio waves. A Wi-Fi router connects to the internet through a wired connection, and it emits wireless signals that devices like smartphones and laptops can detect and connect to.',
#  "Latency in online gaming refers to the delay between a player's actions and the corresponding response on the game server. Low latency is crucial for a smooth gaming experience, as high latency can lead to input lag and disrupted gameplay.",
#  'A satellite communication system involves the use of artificial satellites to transmit and receive signals for various communication purposes. These satellites relay signals over long distances, enabling global communication for services like television broadcasting and internet access.',
#  "VoLTE stands for Voice over Long-Term Evolution. It's a technology that enables voice calls to be made over 4G LTE networks, providing higher voice quality and faster call setup times compared to traditional 2G or 3G networks.",
#  'A modem is a device that modulates and demodulates digital data to enable communication between computers over various transmission mediums, such as telephone lines or cable networks.',
#  'Latency in telecommunication refers to the time delay between sending data from a source to its destination and receiving a response. It can result from various factors such as signal propagation time, data processing, and network congestion.',
#  'Bandwidth throttling, also known as bandwidth shaping or rate limiting, is a practice used by internet service providers to intentionally reduce the available data transfer rate for certain types of network traffic. This can be used to manage network congestion or enforce data usage policies.',
#  'The OSI (Open Systems Interconnection) model is a conceptual framework used to understand and standardize the functions of a networking or telecommunication system. It consists of seven layers, each responsible for specific aspects of data communication and exchange.',
#  'Fiber-to-the-home (FTTH) is a broadband internet technology that involves deploying optical fiber connections directly to residential homes or buildings. It offers extremely high data transfer speeds and enables various high-bandwidth applications like streaming, online gaming, and video conferencing.',
#  'Session Initiation Protocol (SIP) is a signaling protocol used in telephony and communication systems. It offers benefits such as simplified call setup, multimedia support, flexibility in device types, and the ability to integrate voice, video, and messaging services.',
#  'A wireless router is a device that connects to a wired network and broadcasts a wireless signal, enabling devices like smartphones, laptops, and tablets to access the internet without physical connections.',
#  'A DNS server, or Domain Name System server, is responsible for translating human-readable domain names, like www.example.com, into IP addresses that computers use to locate resources on the internet.',
#  '4G and 5G are generations of cellular networks. 4G offers high-speed data transmission and improved connectivity compared to 3G. 5G, the latest generation, promises even faster data speeds, lower latency, and support for a massive number of connected devices.',
#  "A VPN, or Virtual Private Network, is a secure and encrypted connection between a user's device and a remote server. It's used to enhance online privacy, protect data transmission, and enable remote access to private networks.",
#  'A network switch is a networking device that connects multiple devices in a local area network (LAN) and uses MAC addresses to forward data only to the intended recipient. It enhances network efficiency by reducing network congestion and enabling simultaneous data transmissions.',
#  'VoLTE, or Voice over Long-Term Evolution, is a technology that enables voice calls over 4G LTE networks. It offers superior call quality, faster call setup times, and the ability to simultaneously use data and voice services.',
#  'Telecommunication is the science and practice of transmitting information by electromagnetic means. It involves transmitting large volumes of information over long distances without damaging loss due to noise and interference.',
#  'The basic components of a modern digital telecommunications system must be capable of transmitting voice, data, radio, and television signals. Digital transmission is used for high reliability and cost-effectiveness.',
#  'Digital transmission is preferred due to high reliability and lower costs of digital switching systems. However, analog signals must be converted to digital form before using digital transmission.',
#  'Analog-to-digital conversion is the process of converting analog signals to digital form. It is necessary for using digital transmission with analog signals in voice, radio, and television communication.',
#  'Source encoding involves using formulas to reduce redundant binary information in the digitized signal. It is an essential step after digitization in order to optimize data transmission.',
#  'Channel encoding introduces redundant information to the digitized signal, enabling error detection and correction. It prepares the signal for modulation and transmission.',
#  'Modulation involves superimposing the encoded signal onto a carrier wave. It prepares the signal for transmission over various types of transmission media.',
#  'Multiplexing is the process of combining multiple signals into a single transmission medium. It allows for efficient use of available bandwidth and simultaneous transmission of different data streams.',
#  'During the reverse process at the receiving end, the encoded signal is demodulated to retrieve the digital signal. The information is then passed through a channel decoder and a source decoder to restore the original content.',
#  'The article outlines the components of a digital telecommunications system, including source encoding, channel encoding, modulation, multiplexing, and the reverse process of transmission at the receiving end.',
#  'Analog-to-digital conversion is the process of converting analog signals into digital form. It involves sampling the analog signal at regular intervals, quantizing the amplitude, mapping values to binary digits, and transmitting the digital signal to the receiver for decoding.',
#  'Analog-to-digital conversion involves several steps. First, an analog signal is sampled at regular intervals. Then, the amplitude at each interval is quantized and assigned a value. Next, the values are mapped into a series of binary digits, or bits. Finally, the digital signal is transmitted to the receiver, where it is decoded to reconstitute the original analog signal.',
#  'The binary signal is fundamental to noise-free and distortion-free telecommunication. It consists of only two values, represented by binary digits 1 and 0. This simplicity allows for accurate reception of the signal, as long as noise and distortion do not change the signal from one value to another.',
#  'Analog signals, which vary continuously among a range of values, must be converted to digital form for digital communication systems. The process of analog-to-digital conversion involves sampling the analog signal, quantizing amplitudes, and encoding the values into binary digits. This conversion enables the transmission of analog information through digital channels.',
#  'Sampling is the initial step in analog-to-digital conversion. It involves measuring the amplitude of an analog waveform at regular intervals of time. The rate of variation of the waveform is constrained by its bandwidth, and samples are taken at a frequency determined by the Nyquist interval.',
#  'Quantization follows sampling in analog-to-digital conversion. It involves converting the sampled amplitudes into a finite number of possible values, or levels. The level of quantization is often a power of 2 for easy binary conversion. The process introduces some inaccuracy, known as signal distortion.',
#  'Quantization levels determine the number of possible amplitude values into which a sampled signal is converted. More quantization levels lead to a more accurate representation of the original analog signal, but they also increase the storage or transmission requirements. Proper placement of quantization levels can enhance accuracy and fidelity.',
#  'After quantization, the quantized values are mapped to binary digits using an encoding table. The number of bits required for each value is determined by the number of quantization levels. Higher precision levels require more bits. For example, 256 levels of quantization require 8 bits per sample for binary representation.',
#  'The Huffman code is used in source encoding to minimize the number of bits needed to represent the source. It takes into account the probabilities of different quantization levels, assigning shorter codes to more probable levels. The Huffman code reduces redundancy, enhancing the efficiency of data transmission.',
#  "The Lempel-Ziv algorithm enhances compression by constructing a codebook based on sequences encountered previously. It encodes repeated sequences efficiently, adapting to unknown probabilities of occurrence. This algorithm can compress transmissions of English text by about 55%, compared to the Huffman code's compression of around 43%.",
#  'The channel encoder adds redundancy to the transmitted signal to protect against errors caused by noise during transmission. This process, known as error-control coding, is used to ensure reliable communication and correct errors that may occur during transmission. Error-control codes are applied in various applications, including satellite communication, mobile radio communication, and computer networking.',
#  'Two common methods for error protection are forward error control (FEC) and automatic repeat request (ARQ). In FEC, extra redundant bits are added to protect information bits against errors. In ARQ, redundant bits are used by the receiver to detect errors and request retransmission. FEC requires fewer extra bits to detect errors, while ARQ requires more redundant bits for error detection and correction.',
#  'Forward error control (FEC) involves adding extra redundant bits to the transmitted information. These redundant bits allow the decoder to determine the location and correction of errors that occur during transmission. The advantage of FEC is that it requires fewer extra bits for error detection, making it an efficient method for error protection.',
#  'In automatic repeat request (ARQ), redundant bits are added to the transmitted information for error detection. The receiver uses these bits to detect errors and signals the need for a repeat transmission if errors are detected. ARQ is effective at error detection but requires more redundant bits compared to FEC, as it aims to correct errors as well.',
#  'A repetition code involves sending each data bit multiple times. For example, in a repetition code of block-length three and rate one-third, each data bit is sent three times. The receiver uses a majority vote mechanism to determine the original bit value from the repeated transmissions. This approach increases error resilience, as at least two out of three transmissions must be in error to cause a reception error.',
#  'The Hamming code is an FEC method that adds three redundant bits to a four-bit information signal. A code word consists of seven bits, including four information bits and three redundant bits. The parity bits are chosen to ensure even parity for specific sets of information bits. The Hamming code can correct a single channel error by recalculating parity checks, enhancing error correction in the transmitted signal.',
#  "In block coding, information bits are blocked into finite-length sequences, and redundancy bits are added to create code words. Convolutional encoding, however, doesn't segment encoder output into blocks. It operates as a continuous stream of bits, incorporating memory to determine output based on current and preceding blocks of information bits. Convolutional encoding offers enhanced error-correcting performance but requires a more complex decoding algorithm.",
#  "In convolutional encoding, memory is used to incorporate previous blocks of information bits along with the current block. This helps determine the encoder's output. The encoder operates by shifting among a finite number of states or nodes, where the current and previous information bits influence the output. More memory states result in better error-correcting performance, but this comes at the cost of a more complex decoding process.",
#  'Trellis coding is a coding scheme used in high-speed modems. Unlike convolutional encoding, which produces a stream of bits, trellis encoding generates a sequence of modulation symbols. At the transmitter, trellis-coded modulation combines channel encoding with modulation. At the receiver, decoding and demodulation are jointly performed to optimize error correction performance.',
#  'Modulation is the process of varying some characteristic of a carrier wave in accordance with an information signal, or modulating wave. This process is used to represent an information-bearing signal with a waveform that can accurately pass through a transmission medium. The modulated signal is transmitted over a channel and the original information is recovered through demodulation.',
#  "Modulation is necessary for several reasons. Firstly, transmission channels often have limited passbands, passing only certain frequency ranges without significant attenuation. Modulation helps 'fit' information signals to permitted frequency ranges. Secondly, multiple users often share communication channels, requiring each user's signal to be modulated onto an assigned frequency to avoid interference. Modulation also enables practical transmission when the communication channel supports direct transmission, as in the case of using higher frequencies to reduce antenna size.",
#  'Amplitude modulation (AM) involves varying the amplitude of a fixed-frequency carrier wave proportionally to the information signal. AM is used to modulate analog signals, such as voice, audio, and video signals. It is a technique to encode information onto a carrier wave, making it suitable for transmission over communication channels.',
#  'Frequency modulation (FM) involves varying the frequency of a fixed-amplitude carrier wave based on the information signal. FM is employed to modulate analog signals and is particularly known for its use in FM radio broadcasts. It is utilized to transmit audio and voice signals with improved noise resistance compared to amplitude modulation.',
#  "Digital modulation translates digital data and other digitized information onto an analog carrier wave. This is achieved by modifying the carrier's amplitude, frequency, or phase. Digital modulation is employed to transmit computer data and other digital information over communication channels.",
#  "Amplitude-shift keying (ASK) is a digital modulation technique that changes the amplitude of a carrier wave to reflect binary data. When transmitting a '1', a burst of radio frequency is sent, and it's stopped for a '0'. ASK can also use a shift between predefined amplitudes to represent '0' and '1'.",
#  "Frequency-shift keying (FSK) involves changing the frequency of a carrier wave to indicate binary data. In its basic form, two frequencies are used: one for '0' and another for '1'. FSK was used in early voiceband modems for data transmission over telephone networks.",
#  "Phase-shift keying (PSK) is a digital modulation method where the phase of a carrier wave is altered to convey binary data. Basic PSK uses fixed phases for '0' and '1', such as 0° and 180°. The Bell 212 modem, for instance, employed PSK to transmit data over the public switched telephone network.",
#  "Multiplexing is used to share a communications channel among multiple users to reduce installation costs. When the channel's capacity exceeds that of a single user, multiplexing methods are employed. These methods involve local combining of signals at a common point to enable effective channel sharing. The two commonly used types of multiplexing are frequency-division multiplexing (FDM) and time-division multiplexing (TDM).",
#  "Frequency-division multiplexing (FDM) involves sharing a channel by modulating each user's signal onto a different carrier frequency. The modulated signals are combined, and each user is assigned a specific frequency band. FDM is used when the channel's bandwidth allows for multiple users' signals without overlap. It's employed in systems like old long-distance telephone transmission, coaxial cable systems, and point-to-point microwave systems.",
#  "Time-division multiplexing (TDM) interleaves time segments from different signals onto a single transmission path. This is possible when the channel's data rate is higher than the combined data rates of all users. TDM is applied mainly to digital signals. In TDM, each user's data is presented to a time-division multiplexer, and a scanning switch selects data from each user in sequence to create a composite TDM signal. TDM is widely used in modern telecommunications systems for long-distance transmission.",
#  "While time-division multiplexing (TDM) can theoretically be applied to analog signals, it's predominantly used for digital signals. TDM involves interleaving segments of different signals, making it more convenient for digital data. TDM systems assume synchronization between data paths, making it easier to combine digital signals in sequence. In practice, TDM is primarily employed for digital transmission in modern telecommunications.",
#  "Frequency-division multiplexing (FDM) involves modulating users' signals onto different carrier frequencies. These modulated signals are combined into a complex group signal. To avoid signal overlap, guard bands of unused frequency spectrum are inserted between modulated signals. FDM forms a hierarchy of signal combinations, increasing bandwidth and voice-carrying capacity.",
#  "In time-division multiplexing (TDM), data from multiple users are interleaved onto a single transmission path. A scanning switch selects data from each user in sequence, forming a composite TDM signal. Users' data paths must be time-aligned and synchronized with the scanning mechanism. TDM assigns specific time slots to each user, and the switch advances to select different time slots, thereby ensuring separation of data.",
#  'Three schemes are used for efficient sharing of a single channel in telecommunications: frequency-division multiple access (FDMA), time-division multiple access (TDMA), and code-division multiple access (CDMA). These techniques can be used alone or in combination, and they are well demonstrated by advanced mobile cellular systems.',
#  'FDMA divides the frequency spectrum into slots, and signals of different users are placed in separate frequency slots. Since the frequency spectrum is limited and there are more users than available slots, efficient slot management is essential. In systems like the advanced mobile phone system (AMPS), callers use separate frequency slots. Released slots are reassigned by a network-managing computer at the cellular base station. AMPS aims to reuse frequency slots to accommodate more callers by reassigning slots within cells and allowing simultaneous use in different cells.',
#  "In TDMA, time is divided into slots, and users' signals are placed in separate time slots. Random requests for slots can lead to situations where the number of requests exceeds available slots. In such cases, data needs to be buffered until slots become available. The IS54 cellular system employs TDMA to interleave three digital signals, transmitting them in a 30-kilohertz frequency slot that would be occupied by one analog signal in AMPS. Although buffering introduces some delay, it's usually not noticeable during a call.",
#  'In CDMA, signals are sent simultaneously in the same frequency band. Receivers select or reject signals based on user-specific signature waveforms created from assigned spreading codes. The IS95 cellular system uses CDMA, where analog speech signals are quantized, organized into digital frames, and then encoded. Interleaved data bits determine which of 64 possible waveforms to transmit, each with a specific polarity pattern. The waveform is spread using a code sequence, occupying a larger bandwidth.',
#  'CDMA sends signals simultaneously in the same frequency band and uses signature waveforms to differentiate users. Unlike FDMA, which assigns separate frequency slots, and TDMA, which divides time into slots, CDMA uses spreading codes to separate signals at the receiver based on their unique code sequence. This spread-spectrum multiple access (SSMA) technique eliminates the need for frequency management found in FDMA.',
#  "Telecommunication is the transmission of information using technologies like wire, radio, optical, or electromagnetic systems. It originated from humans' desire for communication over longer distances than the human voice could cover efficiently. Slow systems like postal mail are excluded. The goal was to achieve expediency in communication over longer distances.",
#  'Transmission media in telecommunication have evolved through various technological stages. This evolution includes visual signals like beacons, smoke signals, semaphore telegraphs, signal flags, and optical heliographs. It also involves electrical cable and electromagnetic radiation, including light. Communication paths are often divided into channels that enable multiplexing multiple concurrent communication sessions.',
#  'Examples of pre-modern long-distance communication methods include coded drumbeats, lung-blown horns, and loud whistles. These audio messages were used to transmit information over distances. However, the 20th and 21st centuries saw advancements in electrical and electromagnetic technologies like telegraph, telephone, television, radio, microwave transmission, optical fiber, and communications satellites.',
#  'Pioneering inventors and developers in the field of electrical and electronic telecommunications include Guglielmo Marconi, Charles Wheatstone, Samuel Morse (telegraph inventors), Antonio Meucci, Alexander Graham Bell (telephone inventors), Edwin Armstrong, Lee de Forest (radio inventors), and Vladimir K. Zworykin, John Logie Baird, Philo Farnsworth (television inventors).',
#  'With the rise of digital technologies since the 1960s, data has become a supplement to voice communication. Metallic data transmission limitations led to the development of optical technologies. The development of media-independent Internet technologies has provided worldwide access to services without location or time restrictions.',
#  "Telecommunication is a compound noun originating from the Greek prefix tele- (τῆλε), meaning distant or far off, and the Latin verb communicare, meaning to share. The modern use of the term is adapted from the French language. The term was first recorded in written form in 1904 by the French engineer and novelist Édouard Estaunié. The word 'communication' itself was first used in the English language in the late 14th century. It was derived from Old French 'comunicacion' (14th century, Modern French communication), which comes from Latin 'communicationem,' the noun of action from the past participle stem of 'communicare,' meaning 'to share, divide out; communicate, impart, inform; join, unite, participate in,' and literally, 'to make common,' from 'communis.'",
#  'At the 1932 Plenipotentiary Telegraph Conference and the International Radiotelegraph Conference in Madrid, the two organizations merged to form the International Telecommunication Union (ITU).',
#  "They defined telecommunication as 'any telegraphic or telephonic communication of signs, signals, writing, facsimiles and sounds of any kind, by wire, wireless or other systems or processes of electric signaling or visual signaling (semaphores).' The definition was later reconfirmed, according to Article 1.3 of the ITU Radio Regulations, which defined it as 'Any transmission, emission or reception of signs, signals, writings, images and sounds or intelligence of any nature by wire, radio, optical, or other electromagnetic systems.'",
#  'Homing pigeons have been used throughout history by different cultures. Pigeon post had Persian roots and was later used by the Romans to aid their military. Frontinus claimed Julius Caesar used pigeons as messengers in his conquest of Gaul. The Greeks also conveyed the names of the victors at the Olympic Games to various cities using homing pigeons. In the early 19th century, the Dutch government used the system in Java and Sumatra. And in 1849, Paul Julius Reuter started a pigeon service to fly stock prices between Aachen and Brussels, a service that operated for a year until the gap in the telegraph link was closed.',
#  "In the Middle Ages, chains of beacons were commonly used on hilltops as a means of relaying a signal. Beacon chains suffered the drawback that they could only pass a single bit of information, so the meaning of the message such as 'the enemy has been sighted' had to be agreed upon in advance. One notable instance of their use was during the Spanish Armada, when a beacon chain relayed a signal from Plymouth to London.",
#  'In 1792, Claude Chappe, a French engineer, built the first fixed visual telegraphy system (or semaphore line) between Lille and Paris. However semaphore suffered from the need for skilled operators and expensive towers at intervals of ten to thirty kilometres (six to nineteen miles). As a result of competition from the electrical telegraph, the last commercial line was abandoned in 1880.',
#  "On July 25, 1837, the first commercial electrical telegraph was demonstrated by English inventor Sir William Fothergill Cooke and English scientist Sir Charles Wheatstone. Both inventors viewed their device as 'an improvement to the [existing] electromagnetic telegraph' and not as a new device.",
#  "Samuel Morse independently developed a version of the electrical telegraph that he unsuccessfully demonstrated on September 2, 1837. His code was an important advance over Wheatstone's signaling method.",
#  'The first transatlantic telegraph cable was successfully completed on July 27, 1866, allowing transatlantic telecommunication for the first time.',
#  "The conventional telephone was patented by Alexander Bell in 1876. Elisha Gray also filed a caveat for it in 1876. Gray abandoned his caveat, and because he did not contest Bell's priority, the examiner approved Bell's patent on March 3, 1876.",
#  "Antonio Meucci invented a device that allowed the electrical transmission of voice over a line nearly 30 years before in 1849, but his device was of little practical value because it relied on the electrophonic effect requiring users to place the receiver in their mouths to 'hear.'",
#  'The first commercial telephone services were set up by the Bell Telephone Company in 1878 and 1879 on both sides of the Atlantic in the cities of New Haven and London.',
#  'In 1894, Italian inventor Guglielmo Marconi began developing a wireless communication using the then-newly discovered phenomenon of radio waves, showing by 1901 that they could be transmitted across the Atlantic Ocean.',
#  "On 17 December 1902, a transmission from the Marconi station in Glace Bay, Nova Scotia, Canada, became the world's first radio message to cross the Atlantic from North America.",
#  'After World War I accelerated the development of radio for military communications, commercial radio AM broadcasting began in the 1920s and became an important mass medium for entertainment and news.',
#  'Development of stereo FM broadcasting of radio began in the 1930s in the United States and the 1940s in the United Kingdom, displacing AM as the dominant commercial standard in the 1970s.',
#  "On March 25, 1925, John Logie Baird demonstrated the transmission of moving pictures at the London department store Selfridges. Baird's device relied upon the Nipkow disk and thus became known as the mechanical television.",
#  'The first version of such a television to show promise was produced by Philo Farnsworth and demonstrated to his family on 7 September 1927.',
#  'After World War II, interrupted experiments resumed, and television became an important home entertainment broadcast medium.',
#  'The type of device known as a thermionic tube or thermionic valve uses thermionic emission of electrons from a heated cathode for a number of fundamental electronic functions such as signal amplification and current rectification.',
#  'The simplest vacuum tube, the diode invented in 1904 by John Ambrose Fleming, contains only a heated electron-emitting cathode and an anode. Electrons can only flow in one direction through the device—from the cathode to the anode.',
#  'Adding one or more control grids within the tube enables the current between the cathode and anode to be controlled by the voltage on the grid or grids.',
#  'These devices became a key component of electronic circuits for the first half of the 20th century and were crucial to the development of radio, television, radar, sound recording and reproduction, long-distance telephone networks, and analogue and early digital computers.',
#  'In the 1940s, the invention of semiconductor devices made it possible to produce solid-state devices, which are smaller, cheaper, and more efficient, reliable, and durable than thermionic tubes. Starting in the mid-1960s, thermionic tubes were replaced with the transistor.',
#  'On 11 September 1940, George Stibitz transmitted problems for his Complex Number Calculator in New York using a teletype and received the computed results back at Dartmouth College in New Hampshire. This configuration of a centralized computer (mainframe) with remote dumb terminals remained popular well into the 1970s.',
#  'In the 1960s, Paul Baran and, independently, Donald Davies started to investigate packet switching, a technology that sends a message in portions to its destination asynchronously without passing it through a centralized mainframe. A four-node network emerged on 5 December 1969, constituting the beginnings of the ARPANET, which by 1981 had grown to 213 nodes.',
#  'The effective capacity to exchange information worldwide through two-way telecommunication networks grew from 281 petabytes (pB) of optimally compressed information in 1986 to 471 pB in 1993 to 2.2 exabytes (eB) in 2000 to 65 eB in 2007.',
#  'This is the informational equivalent of two newspaper pages per person per day in 1986, and six entire newspapers per person per day by 2007.',
#  'Given this growth, telecommunications play an increasingly important role in the world economy and the global telecommunications industry was about a $4.7 trillion sector in 2012.',
#  "The service revenue of the global telecommunications industry was estimated to be $1.5 trillion in 2010, corresponding to 2.4% of the world's gross domestic product (GDP).",
#  'A basic telecommunication system consists of three main parts that are always present in some form or another:\n\n- A transmitter that takes information and converts it to a signal\n- A transmission medium, also called the physical channel, that carries the signal (e.g. the "free space channel")\n- A receiver that takes the signal from the channel and converts it back into usable information for the recipient',
#  "In a radio broadcasting station, the station's large power amplifier is the transmitter and the broadcasting antenna is the interface between the power amplifier and the free space channel.",
#  'Telecommunication systems are occasionally "duplex" (two-way systems) with a single box of electronics working as both the transmitter and a receiver, or a transceiver (e.g., a mobile phone). The transmission electronics and the receiver electronics within a transceiver are quite independent of one another.',
#  'Transceivers have to be carefully designed and built to isolate their high-power circuitry and their low-power circuitry from each other to avoid interference.',
#  'Telecommunication over fixed lines is called point-to-point communication because it occurs between a transmitter and a receiver. Telecommunication through radio broadcasts is called broadcast communication because it occurs between a powerful transmitter and numerous low-power but sensitive radio receivers.',
#  'Telecommunications in which multiple transmitters and multiple receivers have been designed to cooperate and share the same physical channel are called multiplex systems. The sharing of physical channels using multiplexing often results in significant cost reduction.',
#  'Communications signals can be sent by analog signals or digital signals via analog communication systems or digital communication systems.',
#  'Analog signals vary continuously with respect to the information, while digital signals encode information as a set of discrete values (e.g., a set of ones and zeroes).',
#  'During propagation and reception, information contained in analog signals is degraded by undesirable physical noise. Unless the additive noise disturbance exceeds a certain threshold, the information contained in digital signals will remain intact. Their resistance to noise represents a key advantage of digital signals over analog signals.',
#  'Analog systems fail gracefully: as noise increases, the signal becomes progressively more degraded but still usable.',
#  "Digital systems fail catastrophically when noise exceeds the system's ability to autocorrect.",
#  'Digital transmission of continuous data unavoidably adds quantization noise to the output. This can be reduced, but not eliminated, only at the expense of increasing the channel bandwidth requirement.',
#  "The term 'channel' has two different meanings. In one meaning, a channel is the physical medium that carries a signal between the transmitter and the receiver. The other meaning of the term 'channel' in telecommunications is seen in the phrase communications channel, which is a subdivision of a transmission medium so that it can be used to send multiple streams of information simultaneously.",
#  'Examples of physical mediums that carry a signal between the transmitter and the receiver include the atmosphere for sound communications, glass optical fibers for some kinds of optical communications, coaxial cables for communications using voltages and electric currents, and free space for communications using visible light, infrared waves, ultraviolet light, and radio waves.',
#  "In the example above, the 'free space channel' has been divided into communications channels according to frequencies, and each channel is assigned a separate frequency bandwidth in which to broadcast radio waves. This system of dividing the medium into channels according to frequency is called 'frequency-division multiplexing'.",
#  "Another way of dividing a communications medium into channels is to allocate each sender a recurring segment of time (a 'time slot'), and to allow each sender to send messages only within its own time slot. This method of dividing the medium into communication channels is called 'time-division multiplexing' (TDM), and is used in optical fibre communication.",
#  'Some radio communication systems use TDM within an allocated FDM channel. Hence, these systems use a hybrid of TDM and FDM.',
#  "The shaping of a signal to convey information is known as modulation. Modulation can be used to represent a digital message as an analog waveform. This is commonly called 'keying'—a term derived from the older use of Morse Code in telecommunications—and several keying techniques exist, such as phase-shift keying, frequency-shift keying, and amplitude-shift keying.",
#  "The 'Bluetooth' system, for example, uses phase-shift keying to exchange information between various devices. In addition, there are combinations of phase-shift keying and amplitude-shift keying which is called 'quadrature amplitude modulation' (QAM) that are used in high-capacity digital radio communication systems.",
#  "Modulation can also be used to transmit the information of low-frequency analog signals at higher frequencies. This is helpful because low-frequency analog signals cannot be effectively transmitted over free space. There are several different modulation schemes available to achieve this, such as amplitude modulation (AM) and frequency modulation (FM). An example of this process is a disc jockey's voice being impressed into a 96 MHz carrier wave using frequency modulation (the voice would then be received on a radio as the channel '96 FM').",
#  'In addition, modulation has the advantage that it may use frequency division multiplexing (FDM).',
#  'A telecommunications network is a collection of transmitters, receivers, and communications channels that send messages to one another.',
#  'Some digital communications networks contain one or more routers that work together to transmit information to the correct user.',
#  'An analog communications network consists of one or more switches that establish a connection between two or more users.',
#  'For both types of networks, repeaters may be necessary to amplify or recreate the signal when it is being transmitted over long distances. This is to combat attenuation that can render the signal indistinguishable from the noise.',
#  'Another advantage of digital systems over analog is that their output is easier to store in memory, i.e. two voltage states (high and low) are easier to store than a continuous range of states.',
#  'On the microeconomic scale, companies have used telecommunications to help build global business empires. This is self-evident in the case of online retailer Amazon.com but, according to academic Edward Lenert, even the conventional retailer Walmart has benefited from better telecommunication infrastructure compared to its competitors.',
#  'On the macroeconomic scale, Lars-Hendrik Röller and Leonard Waverman suggested a causal link between good telecommunication infrastructure and economic growth.',
#  'Because of the economic benefits of good telecommunication infrastructure, there is increasing worry about the inequitable access to telecommunication services amongst various countries of the world—this is known as the digital divide.',
#  'Telecommunication has played a significant role in social relationships. Nevertheless, devices like the telephone system were originally advertised with an emphasis on the practical dimensions of the device...',
#  'In recent years,[when?] the popularity of social networking sites has increased dramatically. These sites allow users to communicate with each other as well as post photographs, events and profiles for others to see.',
#  "In cultural terms, telecommunication has increased the public's ability to access music and film. With television, people can watch films they have not seen before in their own home without having to travel to the video store or cinema. With radio and the Internet, people can listen to music they have not heard before without having to travel to the music store.",
#  'Telecommunication has also transformed the way people receive their news. A 2006 survey (right table) of slightly more than 3,000 Americans by the non-profit Pew Internet and American Life Project in the United States the majority specified television or radio over newspapers.',
#  'Telecommunication has had an equally significant impact on advertising. TNS Media Intelligence reported that in 2007, 58% of advertising expenditure in the United States was spent on media that depend upon telecommunication.',
#  "Many countries have enacted legislation which conforms to the International Telecommunication Regulations established by the International Telecommunication Union (ITU), which is the 'leading UN agency for information and communication technology issues'. In 1947, at the Atlantic City Conference, the ITU decided to 'afford international protection to all frequencies registered in a new international frequency list and used in conformity with the Radio Regulation'.",
#  'From a global perspective, there have been political debates and legislation regarding the management of telecommunication and broadcasting. The history of broadcasting discusses some debates in relation to balancing conventional communication such as printing and telecommunication such as radio broadcasting. The onset of World War II brought on the first explosion of international broadcasting propaganda. Countries, their governments, insurgents, terrorists, and militiamen have all used telecommunication and broadcasting techniques to promote propaganda. Patriotic propaganda for political movements and colonization started the mid-1930s.',
#  'Telecommunication has had an equally significant impact on advertising. TNS Media Intelligence reported that in 2007, 58% of advertising expenditure in the United States was spent on media that depend upon telecommunication.',
#  "Worldwide equipment sales\n\nAccording to data collected by Gartner[69][70] and Ars Technica[71] sales of main consumer's telecommunication equipment worldwide in millions of units was:\nEquipment / year 1975 1980 1985 1990 1994 1996 1998 2000 2002 2004 2006 2008\nComputers 0 1 8 20 40 75 100 135 130 175 230 280\nCell phones N/A N/A N/A N/A N/A N/A 180 400 420 660 830 1000",
#  "In a telephone network, the caller is connected to the person to whom they wish to talk by switches at various telephone exchanges. The switches form an electrical connection between the two users and the setting of these switches is determined electronically when the caller dials the number. Once the connection is made, the caller's voice is transformed to an electrical signal using a small microphone in the caller's handset.",
#  'The broadcast media industry is at a critical turning point in its development, with many countries moving from analog to digital broadcasts. This move is made possible by the production of cheaper, faster and more capable integrated circuits. The chief advantage of digital broadcasts is that they prevent a number of complaints common to traditional analog broadcasts. For television, this includes the elimination of problems such as snowy pictures, ghosting and other distortion. These occur because of the nature of analog transmission, which means that perturbations due to noise will be evident in the final output. Digital transmission overcomes this problem because digital signals are reduced to discrete values upon reception and hence small perturbations do not affect the final output. In a simplified example, if a binary message 1011 was transmitted with signal amplitudes [1.0 0.0 1.0 1.0] and received with signal amplitudes [0.9 0.2 1.1 0.9] it would still decode to the binary message 1011— a perfect reproduction of what was sent. From this example, a problem with digital transmissions can also be seen in that if the noise is great enough it can significantly alter the decoded message. Using forward error correction a receiver can correct a handful of bit errors in the resulting message but too much noise will lead to incomprehensible output and hence a breakdown of the transmission.',
#  'In digital television broadcasting, there are three competing standards that are likely to be adopted worldwide. These are the ATSC, DVB and ISDB standards; the adoption of these standards thus far is presented in the captioned map. All three standards use MPEG-2 for video compression. ATSC uses Dolby Digital AC-3 for audio compression, ISDB uses Advanced Audio Coding (MPEG-2 Part 7) and DVB has no standard for audio compression but typically uses MPEG-1 Part 3 Layer 2.',
#  "In digital audio broadcasting, standards are much more unified with practically all countries choosing to adopt the Digital Audio Broadcasting standard (also known as the Eureka 147 standard). The exception is the United States which has chosen to adopt HD Radio. HD Radio, unlike Eureka 147, is based upon a transmission method known as in-band on-channel transmission that allows digital information to 'piggyback' on normal AM or FM analog transmissions.",
#  'However, despite the pending switch to digital, analog television remains being transmitted in most countries. An exception is the United States that ended analog television transmission (by all but the very low-power TV stations) on 12 June 2009 after twice delaying the switchover deadline. Kenya also ended analog television transmission in December 2014 after multiple delays.',
#  'For analog television, there were three standards in use for broadcasting color TV (see a map on adoption here). These are known as PAL (German designed), NTSC (American designed), and SECAM (French-designed). For analog radio, the switch to digital radio is made more difficult by the higher cost of digital receivers. The choice of modulation for analog radio is typically between amplitude (AM) or frequency modulation (FM). To achieve stereo playback, an amplitude modulated subcarrier is used for stereo FM, and quadrature amplitude modulation is used for stereo AM or C-QUAM.',
#  'The Internet works in part because of protocols that govern how the computers and routers communicate with each other. The nature of computer network communication lends itself to a layered approach where individual protocols in the protocol stack run more-or-less independently of other protocols. This allows lower-level protocols to be customized for the network situation while not changing the way higher-level protocols operate. A practical example of why this is important is because it allows an Internet browser to run the same code regardless of whether the computer it is running on is connected to the Internet through an Ethernet or Wi-Fi connection. Protocols are often talked about in terms of their place in the OSI reference model (pictured on the right), which emerged in 1983 as the first step in an unsuccessful attempt to build a universally adopted networking protocol suite.',
# ...
#  'The physical or geographic locations of network nodes and links generally have relatively little effect on a network, but the topology of interconnections of a network can significantly affect its throughput and reliability. With many technologies, such as bus or star networks, a single failure can cause the network to fail entirely. In general, the more interconnections there are, the more robust the network is; but the more expensive it is to install. Therefore, most network diagrams are arranged by their network topology which is the map of logical interconnections of network hosts.',
#  'Common topologies are:\n\n    - Bus network: all nodes are connected to a common medium along this medium.\n    - Star network: all nodes are connected to a special central node.\n    - Ring network: each node is connected to its left and right neighbor node.\n    - Mesh network: each node is connected to an arbitrary number of neighbors.\n    - Fully connected network: each node is connected to every other node.\n    - Tree network: nodes are arranged hierarchically.\n\nThe physical layout of the nodes in a network may not necessarily reflect the network topology. As an example, with FDDI, the network topology is a ring, but the physical topology is often a star, because all neighboring connections can be routed via a central physical location.',
#  'An overlay network is a virtual network built on top of another network. Nodes in the overlay network are connected by virtual links that correspond to paths in the underlying network. The topology of the overlay network may differ from the underlying one. For example, many peer-to-peer networks are overlay networks. The Internet itself is a prominent example of an overlay network, built on top of the telephone network. Overlay networks have been proposed to improve Internet routing and quality of service, often without requiring modifications to all routers in the network.',
#  "The transmission media used to link devices in a computer network include electrical cable, optical fiber, and free space. Ethernet, a LAN technology, uses copper and fiber media. Wireless LAN standards use radio waves or infrared signals. Power line communication utilizes a building's power cabling for data transmission.",
#  'Wired technologies in computer networking include coaxial cable, twisted pair cabling, and optical fiber. Coaxial cable is used in cable TV systems and local area networks. Twisted pair cabling, with unshielded and shielded forms, is used for Ethernet. Optical fibers carry data via light and are used for long cable runs with high data rates.',
#  'Wireless network connections are established using radio or other electromagnetic communication means. Terrestrial microwave and communication satellites use microwave frequencies. Cellular networks divide areas into regions, each served by a low-power transceiver. Wireless LANs use radio waves and spread spectrum technology, while free-space optical communication uses light. The Interplanetary Internet aims to extend the Internet using radio waves and optical means.',
#  "A network interface controller (NIC) is computer hardware that connects the computer to the network media and can process low-level network information. It may have a connector for cables or aerials for wireless transmission. In Ethernet networks, each NIC has a unique Media Access Control (MAC) address. The MAC address is stored in the controller's permanent memory. NICs play a role in identifying devices on a network.",
#  'A repeater is an electronic device that receives a network signal, removes noise, and regenerates the signal. This retransmission can extend the coverage area of the signal. Repeaters are used to overcome signal degradation over long cable runs in twisted-pair Ethernet setups. With fiber optics, repeaters can span great distances. However, they introduce a propagation delay that may affect network performance.',
#  'Bridges and switches are distinct from hubs because they forward frames only to relevant ports involved in communication. A hub forwards frames to all ports. Bridges have two ports, while switches can have multiple ports. They operate at the data link layer of the OSI model and forward data based on MAC addresses. Bridges and switches segment network collision domains and help create more efficient networks by breaking down congestion.',
#  'A router is an internetworking device that forwards packets between networks by processing routing information. It uses its routing table to determine packet destinations, reducing the need for broadcasting packets. Routers play a crucial role in forwarding data across networks, improving efficiency and scalability.',
#  'Modems (modulator-demodulator) connect network nodes via non-digital mediums or wireless links. They modulate digital signals into analog signals suitable for transmission over the medium. Modems were initially used to send audio signals over standard phone lines. They are still used for DSL technology over phone lines and for DOCSIS technology in cable TV systems.',
#  'A firewall is a network device or software that controls network security and access rules. It is placed between secure internal networks and potentially insecure external networks like the Internet. Firewalls are configured to allow actions from recognized sources while rejecting access from unrecognized ones. They play a vital role in network security, especially in the face of increasing cyber attacks.',
#  'A communication protocol is a set of rules for exchanging information over a network. It defines how data should be structured, transmitted, and received between devices in a network. Communication protocols can be connection-oriented or connectionless, use circuit mode or packet switching, and employ hierarchical or flat addressing.',
#  'Communication functions are divided into protocol layers in a protocol stack, following the OSI model. Each layer leverages the services of the layer below it. The lowest layer controls the hardware that transmits data across the media. This layering allows for modular and efficient communication between devices.',
#  'The TCP/IP model, also known as the Internet protocol suite, forms the foundation of modern networking. It offers services over unreliable networks, using datagram transmission with Internet protocol (IP). It defines addressing, identification, and routing for IPv4 and IPv6. The TCP/IP model is crucial for defining protocols for the Internet.',
#  'The IEEE 802 protocol suite comprises a range of standards for local and metropolitan area networks. These protocols operate mostly at layers 1 and 2 of the OSI model. IEEE 802.1D deals with MAC bridging and Ethernet packet routing. IEEE 802.1Q defines VLANs, and IEEE 802.1X establishes port-based Network Access Control protocols.',
#  'Ethernet is a family of technologies used in wired LANs. It is described by the IEEE 802.3 standards published by the Institute of Electrical and Electronics Engineers. Ethernet defines how devices in a network share a common communication medium and access it using Carrier Sense Multiple Access with Collision Detection (CSMA/CD).',
#  'IEEE 802.11, also known as WiFi, is a widely used standard for wireless LANs. It shares many properties with wired Ethernet and operates at layers similar to those in wired networks. Devices using IEEE 802.11 can communicate wirelessly in a manner similar to Ethernet communication in wired networks.',
#  'Synchronous optical networking (SONET) and Synchronous Digital Hierarchy (SDH) are multiplexing protocols used to transfer multiple digital bit streams over optical fiber. They were designed for circuit-switched digital telephony, but also support Asynchronous Transfer Mode (ATM) frames due to their protocol neutrality and transport-oriented features.',
#  'Asynchronous Transfer Mode (ATM) is a switching technique for telecommunication networks that encodes data into fixed-sized cells using asynchronous time-division multiplexing. It differs from other protocols like the Internet protocol suite and Ethernet, which use variable-sized packets or frames. ATM is suitable for both high-throughput data traffic and real-time content like voice and video, making it versatile.',
#  'Cellular standards such as GSM, CDMA2000, and UMTS define digital cellular communication. These standards enable voice and data communication in mobile networks. They use various technologies like Global System for Mobile Communications (GSM), Code Division Multiple Access (CDMA), and Universal Mobile Telecommunications System (UMTS) to facilitate wireless communication.',
#  'Routing is the process of determining the best paths through a network for information to travel from a source to a destination. It involves selecting the most efficient route for data packets to follow, considering factors like distance, congestion, and network topology.',
#  'In packet-switched networks, routing protocols direct the forwarding of data packets through intermediate nodes, such as routers, bridges, and switches. These protocols determine the paths that packets should take based on factors like network conditions and destination addresses.',
#  'In routing, intermediate nodes like routers, bridges, gateways, firewalls, and switches play a crucial role. These devices direct data packets through the network to reach their intended destinations by following the routes defined by routing protocols.',
#  'Routing tables maintain records of various network routes, including destination addresses and associated paths. These tables are consulted by routing algorithms to determine the optimal path for forwarding data packets to their intended destinations.',
#  'Routing assumes that network addresses are structured, implying proximity within the network. This allows for the use of structured addressing and efficient routing tables. In contrast, bridging does not require structured addresses and often uses unstructured MAC addresses for forwarding data within local area networks (LANs).',
#  'A home area network (HAN) is a network that connects digital devices within a residential setting. It typically includes personal computers, printers, phones, PDAs, and other devices. A HAN may share Internet access, often through broadband connections like cable or DSL.',
#  'A storage area network (SAN) is a dedicated network that provides access to consolidated, block-level data storage. It allows storage devices like disk arrays and tape libraries to be accessed by servers as if they were locally attached devices.',
#  'A backbone network interconnects different local area networks (LANs) or subnetworks within a larger network infrastructure. It provides a path for exchanging information between these interconnected networks and typically has greater capacity than the individual networks it connects.',
#  'A wide area network (WAN) spans a large geographic area and uses various transmission media like telephone lines, cables, and airwaves to connect different locations. WAN technologies operate across the physical, data link, and network layers of the OSI model, facilitating communication over extended distances.',
#  "The Internet is a global network composed of interconnected networks, enabling the exchange of information and services across the world. It utilizes networking technologies from the Internet protocol suite, based on the IP addressing system. The Internet's backbone includes a massive system of fiber-optic cables and optical networking.",
#  'Network services are applications hosted by servers on a computer network, providing functionality for network members or users. These services can include the World Wide Web, E-mail, printing, network file sharing, and more.',
#  'Examples of well-known network services include the World Wide Web, E-mail, Domain Name System (DNS), and Dynamic Host Configuration Protocol (DHCP). These services provide functionalities such as accessing websites, sending emails, converting names to IP addresses, and managing IP addresses.',
#  'Bandwidth in computing refers to the rate of data transfer through a communication path. It can be consumed bandwidth, achieved throughput, or goodput. Bandwidth is affected by technologies like bandwidth shaping, bandwidth management, and others.',
#  'Network delay is the time it takes for data to travel across a telecommunications network from one communication endpoint to another. It includes different components like processing delay, queuing delay, transmission delay, and propagation delay.',
#  'Quality of service (QoS) in network performance involves parameters such as throughput, jitter, bit error rate, and latency. It ensures that network services meet specific performance criteria, providing a reliable and consistent user experience.',
#  'Network congestion occurs when a link or node is overloaded with more data than it can handle, resulting in degraded quality of service. Congestion leads to effects like queuing delay, packet loss, and blocking of new connections.',
#  "Network resilience refers to a network's ability to maintain an acceptable level of service in the face of faults and challenges. It is crucial for ensuring that the network can continue to operate even during disruptions or abnormal conditions.",
#  "Network security involves provisions and policies to prevent unauthorized access, misuse, or modification of a computer network and its resources. It's essential to protect sensitive data, transactions, and communications from unauthorized access and threats.",
#  'End-to-end encryption (E2EE) ensures the protection of data between two communicating parties. It prevents intermediaries from accessing or tampering with communications. E2EE is used in various communication systems, like HTTPS, PGP for email, and OTR for instant messaging.',
#  'SSL (Secure Socket Layer) and TLS (Transport Layer Security) are cryptographic protocols that enhance network security. They provide authentication, encryption, and data integrity, ensuring secure communication between clients and servers over the Internet.',
#  'Users and network administrators have different perspectives on networks. Users often share resources like printers within a workgroup on the same LAN, while Network Administrators ensure network stability. A community of interest involves geographically dispersed users sharing servers and using peer-to-peer technologies.',
#  'Network administrators view networks from both physical and logical angles. The physical perspective includes geography, cabling, and interconnecting network elements like routers. Logical networks, or subnets in TCP/IP, map onto transmission media. For instance, LAN cables in a building can form a subnet using VLAN technology.',
#  'An intranet is a private network administered by an enterprise, accessible only by authorized users. It need not be connected to the Internet. An extranet extends an intranet, allowing secure communication with external users like business partners or customers.',
#  'The Internet consists of interconnected users, enterprises, and content providers linked by Internet Service Providers (ISPs). It comprises subnets and subnet aggregates that share registered IP address space and use the Border Gateway Protocol for IP reachability information. Domain Name System (DNS) translates server names to IP addresses.',
#  'Over the Internet, there are business-to-business (B2B), business-to-consumer (B2C), and consumer-to-consumer (C2C) communications. Sensitive or financial exchanges usually involve communication security mechanisms. Intranets and extranets can use secure Virtual Private Network (VPN) technology over the Internet.']

# %%
answers
# Out:
# ['A modem is a communication device that converts digital data to analog and vice versa, enabling computers to communicate over telephone lines.',
#  'The purpose of a router is to forward data packets between different computer networks. It plays a key role in managing data flow and ensuring efficient communication.',
#  'Bandwidth in telecommunication refers to the maximum rate at which data can be transmitted over a network connection. It indicates the data capacity within a specific time frame.',
#  'Latency in telecommunication refers to the time delay between data transmission and reception within a network. It can have effects on real-time communication applications and online gaming experiences.',
#  'VoIP, or Voice over Internet Protocol, is a technology enabling voice communication and multimedia sessions over the Internet. It enables phone calls and other forms of communication using data networks.',
#  'The role of a network firewall is to provide security by monitoring and regulating incoming and outgoing network traffic. It serves as a protective barrier between trusted internal networks and potentially harmful external networks.',
#  'The key difference between 4G and 5G lies in their speed and latency capabilities. While 4G provides relatively fast data speeds, 5G offers much higher data transfer rates and significantly lower latency. This makes 5G suitable for various innovative applications like augmented reality and remote surgery.',
#  'A fiber optic cable is a high-speed transmission medium constructed from glass or plastic fibers. It employs light signals to carry data over extended distances, experiencing minimal signal degradation and susceptibility to electromagnetic interference.',
#  'Wi-Fi operates through radio wave transmission. A Wi-Fi router connects to the internet via a wired link and emits wireless signals detectable by devices such as smartphones and laptops. These devices can then establish wireless connections to the router, enabling internet access.',
#  "In online gaming, latency represents the time delay between a player's input and the server's response. Low latency is essential for optimal gameplay, as high latency can cause input delays and disrupt the overall gaming experience.",
#  'Satellite communication systems employ artificial satellites to transmit and receive signals across extensive distances. These satellites facilitate global communication, supporting services like television broadcasting and internet connectivity.',
#  'VoLTE, which stands for Voice over Long-Term Evolution, allows voice calls to be conducted over 4G LTE networks. This technology offers improved voice quality and quicker call setup durations in contrast to older 2G or 3G networks.',
#  'A modem is a communication device that converts digital data from computers into analog signals suitable for transmission over analog communication lines, and vice versa. It plays a crucial role in enabling computers to communicate over different types of networks.',
#  'Latency in telecommunication signifies the time delay experienced by data as it travels from its origin to its destination and receives a response. Factors like signal propagation, data processing, and network congestion contribute to latency in communication networks.',
#  "Bandwidth throttling, or bandwidth shaping, refers to the intentional slowing down of data transfer rates for specific types of network traffic by internet service providers. It's often used to regulate network congestion, allocate resources, or enforce data usage policies.",
#  'The OSI (Open Systems Interconnection) model serves as a conceptual blueprint for comprehending and standardizing networking and telecommunication systems. It encompasses seven distinct layers, each dedicated to specific functions involved in transmitting and receiving data.',
#  'Fiber-to-the-home (FTTH) is a broadband technology that entails connecting individual homes or buildings to the internet through dedicated optical fiber lines. This technology delivers exceptionally fast data speeds, supporting bandwidth-intensive applications like streaming, online gaming, and video conferencing.',
#  'Session Initiation Protocol (SIP) is a signaling protocol employed in telephony and communication networks. Its advantages include streamlined call establishment, support for multimedia content, compatibility across various devices, and the capacity to integrate voice, video, and messaging functionalities.',
#  "A wireless router operates by receiving data from a wired network connection and then transmitting it wirelessly using radio waves. Devices within range can connect to the router's network using Wi-Fi, allowing them to access the internet.",
#  'A DNS server plays a critical role in networking by converting user-friendly domain names into numerical IP addresses. This translation enables computers to locate and communicate with specific resources and services on the internet.',
#  '4G and 5G represent different generations of cellular networks. While 4G provides enhanced data transfer rates and connectivity compared to its predecessor 3G, 5G takes connectivity to the next level with faster data speeds, lower latency, and the capacity to support a vast array of interconnected devices.',
#  "A VPN, or Virtual Private Network, establishes a secure and encrypted link between a user's device and a remote server. This technology is employed in telecommunications to bolster online privacy, safeguard data during transmission, and facilitate secure access to private networks from remote locations.",
#  'A network switch is a key component in data communication, facilitating connections between devices within a local area network (LAN). It utilizes MAC addresses to forward data specifically to the intended recipient, thereby optimizing network performance by mitigating congestion and enabling efficient data transfers.',
#  'VoLTE, or Voice over Long-Term Evolution, revolutionizes voice calls by leveraging 4G LTE networks. It delivers enhanced call quality, quicker call setup durations, and the capability to seamlessly utilize voice and data services concurrently, setting it apart from traditional voice calls.',
#  'Telecommunication is the science and practice of transmitting information using electromagnetic methods. It focuses on transmitting large amounts of data over long distances while minimizing loss from noise and interference.',
#  'The basic components of a modern digital telecommunications system are designed to transmit voice, data, radio, and television signals. Digital transmission is employed for reliability and cost efficiency.',
#  'Digital transmission is preferred because of its high reliability and the cost advantages of digital switching systems. Analog signals must be converted to digital form before using digital transmission.',
#  "Analog-to-digital conversion involves transforming analog signals into digital format. It's essential when using digital transmission with analog signals in voice, radio, and television communication.",
#  "Source encoding is the process of applying formulas to minimize redundant binary information in the digitized signal. It's a crucial step after digitization to enhance data transmission efficiency.",
#  'Channel encoding adds redundant information to the digitized signal, allowing for error detection and correction. It readies the signal for modulation and eventual transmission.',
#  'Modulation entails overlaying the encoded signal onto a carrier wave. This step is necessary to prepare the signal for transmission over different types of transmission media.',
#  'Multiplexing involves merging several signals into a single transmission medium. This technique optimizes bandwidth utilization and enables simultaneous transmission of diverse data streams.',
#  'In the reverse process at the receiving end, the encoded signal is demodulated to recover the digital signal. The data is subsequently passed through a channel decoder and a source decoder to restore the original information.',
#  'The article describes several components of a digital telecommunications system, such as source encoding, channel encoding, modulation, multiplexing, and the reverse process of transmission at the receiving end.',
#  'Analog-to-digital conversion is the process of converting analog signals to digital form. It includes sampling, quantization, mapping to binary digits, and transmission to the receiver for decoding.',
#  'Analog-to-digital conversion includes sampling the analog signal, quantizing the amplitude, mapping values to binary digits, and transmitting the digital signal for decoding at the receiver.',
#  "The binary signal is crucial for noise-free telecommunication. It comprises binary digits 1 and 0, representing two possible values. Accurate reception is possible if noise and distortion don't alter the signal's value.",
#  'Analog-to-digital conversion is needed to convert continuous analog signals to digital form for digital communication. It involves sampling, quantization, and binary encoding, allowing analog information to be transmitted through digital channels.',
#  "Sampling is the first stage of analog-to-digital conversion. It entails measuring the amplitude of an analog waveform at regular time intervals. Samples are taken based on the waveform's bandwidth and the Nyquist interval.",
#  'Quantization is the step after sampling in analog-to-digital conversion. It transforms sampled amplitudes into a finite set of possible levels. These levels are often powers of 2 for binary conversion. The process introduces a degree of inaccuracy, leading to signal distortion.',
#  'Quantization levels determine the discrete amplitude values for a sampled signal. More levels result in greater accuracy, but they also increase storage or transmission needs. Proper placement of levels enhances accuracy and fidelity.',
#  'Following quantization, quantized values are converted to binary digits using an encoding table. Bits required for each value depend on quantization levels. More levels need more bits. For instance, 256 quantization levels need 8 bits for binary representation per sample.',
#  'The Huffman code is essential for source encoding to reduce bit usage in representing the source. It uses probabilities to assign shorter codes to more likely levels. By reducing redundancy, the Huffman code improves data transmission efficiency.',
#  "The Lempel-Ziv algorithm boosts compression by creating a codebook from previously encountered sequences. It efficiently encodes repeated sequences, adapting to unknown probabilities. It compresses English text transmissions by about 55%, surpassing the Huffman code's 43% compression.",
#  'The purpose of the channel encoder is to add redundancy to the transmitted signal, protecting against errors due to noise during transmission. This error-control coding ensures reliable communication and error correction in applications such as satellite communication and computer networking.',
#  'The two primary methods for protecting transmitted information from errors are forward error control (FEC) and automatic repeat request (ARQ). FEC adds extra redundant bits, while ARQ uses redundant bits for error detection and requesting retransmission.',
#  "Forward error control (FEC) adds redundant bits to transmitted information, aiding the decoder in identifying and correcting errors. FEC's advantage is its efficiency in requiring fewer extra bits for error detection.",
#  'Automatic repeat request (ARQ) adds redundant bits for error detection. If errors are detected, the receiver requests a repeat transmission. ARQ excels in error detection, but it requires more redundant bits than FEC to correct errors.',
#  "A repetition code sends each data bit multiple times. In a block-length three repetition code, each bit is transmitted three times. The receiver uses a majority vote to decide the bit's original value. This increases error resilience, requiring at least two out of three transmissions to be erroneous for a reception error.",
#  'The Hamming code is an FEC technique adding three redundant bits to a four-bit information signal. Code words contain seven bits, including four information bits and three redundant bits. Parity bits are selected to maintain even parity for certain information bit sets. The Hamming code corrects a single channel error by recomputing parity checks.',
#  'Block coding segments information into finite-length sequences and adds redundancy bits. Convolutional encoding operates with a continuous stream of bits, incorporating memory to determine output. It provides improved error-correcting performance but necessitates a more complex decoding algorithm.',
#  "Memory in convolutional encoding incorporates previous information blocks with the current block to determine the encoder's output. The encoder shifts among states, with current and previous bits influencing output. More memory states lead to improved error-correcting performance, though at the expense of a more complex decoding process.",
#  'Trellis coding, found in high-speed modems, generates modulation symbol sequences. Unlike convolutional encoding, it combines channel encoding and modulation at the transmitter. At the receiver, decoding and demodulation are performed together to optimize error correction.',
#  "Modulation in telecommunications is the process of varying a carrier wave's characteristic according to an information signal, allowing the information to accurately pass through a transmission medium. The modulated signal is transmitted and the original information is retrieved through demodulation.",
#  'Modulation is essential in telecommunications for various reasons. It adapts information signals to transmission channels with limited passbands, ensures multiple users can share channels without interference, and makes practical transmission feasible by using higher frequencies to reduce antenna size.',
#  'Amplitude modulation (AM) varies the amplitude of a fixed-frequency carrier wave according to the information signal. AM is used to modulate analog signals, making them suitable for transmission over communication channels.',
#  'Frequency modulation (FM) changes the frequency of a fixed-amplitude carrier wave in response to the information signal. FM is used to modulate analog signals, notably in FM radio broadcasts. It offers better noise resistance compared to amplitude modulation when transmitting audio and voice signals.',
#  'Digital modulation translates digitized information onto an analog carrier wave by adjusting its amplitude, frequency, or phase. This process is used to transmit computer data and other digital information over communication channels.',
#  "Amplitude-shift keying (ASK) is a digital modulation method altering the amplitude of a carrier wave to represent binary data. A burst of radio frequency is transmitted for '1' and stopped for '0'. ASK can use amplitude shifts to denote '0' and '1' as well.",
#  "Frequency-shift keying (FSK) alters the frequency of a carrier wave to represent binary data. Two frequencies are used, one for '0' and another for '1'. FSK was employed in early voiceband modems to transmit data over telephone networks.",
#  "Phase-shift keying (PSK) is a digital modulation technique changing the phase of a carrier wave for binary data transmission. '0' is sent with a fixed phase, while '1' is sent with an opposite 180° phase. The Bell 212 modem utilized PSK for data transmission over the telephone network.",
#  'The purpose of multiplexing in telecommunications is to allow multiple users to share a communications channel, thereby reducing installation costs. It involves combining signals at a common point using methods like frequency-division multiplexing (FDM) and time-division multiplexing (TDM).',
#  "Frequency-division multiplexing (FDM) shares a channel by modulating users' signals onto distinct carrier frequencies. These modulated signals are combined, and users are assigned specific frequency bands. FDM is used when the channel's bandwidth accommodates multiple signals without overlap. It's utilized in long-distance telephone transmission, coaxial cable systems, and point-to-point microwave systems.",
#  "Time-division multiplexing (TDM) interleaves time segments from different signals onto a single transmission path. It's feasible when the channel's data rate exceeds the combined user data rates. TDM is mainly applied to digital signals. Each user's data is presented to a multiplexer, and a scanning switch selects data in sequence to form a composite TDM signal. TDM is commonly used in modern long-distance telecommunications systems.",
#  "Although time-division multiplexing (TDM) can be applied to analog signals in theory, it is primarily used for digital signals. TDM's interleaving process suits digital data better, assuming synchronized data paths. In modern telecommunications, TDM is predominantly used for digital transmission.",
#  "Frequency-division multiplexing (FDM) combines users' modulated signals into a complex group signal. To prevent overlap, guard bands of unused spectrum are inserted between modulated signals. FDM establishes a hierarchy of signal combinations, progressively increasing bandwidth and voice-carrying capacity.",
#  'Time-division multiplexing (TDM) interleaves data from various users onto a single path. A scanning switch selects data sequentially, creating a composite TDM signal. User data paths must be synchronized, and TDM assigns distinct time slots to each user. The scanning switch advances to ensure data separation by selecting different time slots.',
#  'The three schemes for efficient sharing of a single channel in telecommunications are frequency-division multiple access (FDMA), time-division multiple access (TDMA), and code-division multiple access (CDMA). These methods can be used individually or together in various systems.',
#  "Frequency-division multiple access (FDMA) divides the frequency spectrum into slots for different users' signals. It's used to manage communication in systems like the advanced mobile phone system (AMPS), where separate frequency slots are assigned to callers. Reassigned frequency slots within cells and simultaneous use in separate cells help accommodate more callers.",
#  "Time-division multiple access (TDMA) divides time into slots for users' signals. Random slot requests can lead to situations where requests exceed available slots, requiring data buffering. In the IS54 cellular system, TDMA interleaves three digital signals in a 30-kilohertz frequency slot, buffering data to manage delays introduced by buffering.",
#  "Code-division multiple access (CDMA) involves sending signals simultaneously in the same frequency band. Receivers distinguish signals using user-specific signature waveforms generated from spreading codes. The IS95 cellular system utilizes CDMA, quantizing analog speech signals, organizing them into digital frames, and encoding them. Interleaved data bits select from 64 possible waveforms, each with a unique polarity pattern. The waveform is spread using a code sequence, spreading the signal's power over a wider bandwidth.",
#  'CDMA distinguishes itself by sending signals simultaneously in the same frequency band and using user-specific signature waveforms. Unlike FDMA and TDMA, which rely on frequency or time slot separation, CDMA employs spreading codes to separate signals at the receiver. This spread-spectrum multiple access (SSMA) technique eliminates the frequency management required in FDMA.',
#  'Telecommunication originated from the need for communication beyond the range of the human voice, with a similar level of speed. Slow systems like postal mail are excluded. The purpose was to enable efficient communication over longer distances.',
#  'The transmission media in telecommunication have evolved from visual signals like beacons and smoke signals to electrical cable and electromagnetic radiation, including light. Communication channels allow multiplexing multiple concurrent communication sessions.',
#  'Pre-modern long-distance communication methods included coded drumbeats, lung-blown horns, and loud whistles. In the 20th and 21st centuries, advancements in electrical and electromagnetic technologies like telegraph, telephone, television, radio, microwave transmission, optical fiber, and communications satellites became prominent.',
#  'Pioneering inventors and developers in the field of electrical and electronic telecommunications include Guglielmo Marconi, Charles Wheatstone, Samuel Morse, Antonio Meucci, Alexander Graham Bell, Edwin Armstrong, Lee de Forest, Vladimir K. Zworykin, John Logie Baird, and Philo Farnsworth.',
#  'The proliferation of digital technologies since the 1960s has led to the integration of data with voice communication. Optical technologies emerged due to limitations in metallic data transmission. Media-independent Internet technologies have provided global access to services without constraints on location or time.',
#  "The term 'telecommunication' comes from the Greek prefix tele- (τῆλε), meaning distant or far off, and the Latin verb communicare, meaning to share. It was first recorded in written form in 1904 by the French engineer and novelist Édouard Estaunié. The word 'communication' itself was first used in English in the late 14th century, derived from Latin 'communicare,' meaning 'to share, divide out; communicate, impart, inform; join, unite, participate in,' and literally, 'to make common.'",
#  'The International Telecommunication Union (ITU) was formed by the merger of the Plenipotentiary Telegraph Conference and the International Radiotelegraph Conference.',
#  "Telecommunication was defined by the International Telecommunication Union (ITU) as 'any telegraphic or telephonic communication of signs, signals, writing, facsimiles and sounds of any kind, by wire, wireless or other systems or processes of electric signaling or visual signaling (semaphores).' Additionally, the ITU Radio Regulations later reconfirmed this definition, stating it as 'Any transmission, emission or reception of signs, signals, writings, images and sounds or intelligence of any nature by wire, radio, optical, or other electromagnetic systems.'",
#  'Homing pigeons were used by Persian, Roman, Greek, and Dutch cultures and civilizations. They were employed for military aid, conveying messages about Olympic Games winners, and even flying stock prices between Aachen and Brussels.',
#  'Chains of beacons on hilltops in the Middle Ages were used as a means of relaying signals, such as notifying the sighting of the enemy. They had the limitation of passing only a single bit of information, requiring predefined meanings for the messages.',
#  'Claude Chappe, a French engineer, is credited with building the first fixed visual telegraphy system, known as the semaphore line. It was established between Lille and Paris in 1792.',
#  'The first commercial electrical telegraph was demonstrated by Sir William Fothergill Cooke and Sir Charles Wheatstone on July 25, 1837.',
#  "Samuel Morse's code for the electrical telegraph was an important advance over Wheatstone's signaling method.",
#  'The first transatlantic telegraph cable was successfully completed on July 27, 1866, enabling transatlantic telecommunication for the first time.',
#  'The conventional telephone was patented by Alexander Bell in 1876, and the patent was approved on March 3, 1876.',
#  "Antonio Meucci invented a device for the electrical transmission of voice in 1849, but it was of limited practical value as it relied on the electrophonic effect, requiring users to place the receiver in their mouths to 'hear.'",
#  'The first commercial telephone services were set up by the Bell Telephone Company in 1878 and 1879 in the cities of New Haven and London.',
#  'Italian inventor Guglielmo Marconi began developing wireless communication using radio waves and showed by 1901 that radio waves could be transmitted across the Atlantic Ocean.',
#  'The first radio message to cross the Atlantic from North America was transmitted on December 17, 1902, from the Marconi station in Glace Bay, Nova Scotia, Canada.',
#  'Commercial radio AM broadcasting began in the 1920s and became an important mass medium for entertainment and news.',
#  'Stereo FM broadcasting of radio began development in the 1930s and 1940s, replacing AM as the dominant commercial standard in the 1970s.',
#  'John Logie Baird demonstrated the transmission of moving pictures on March 25, 1925, at the London department store Selfridges. His television device relied on the Nipkow disk and was known as the mechanical television.',
#  'Philo Farnsworth produced the first version of a television to show promise and demonstrated it to his family on September 7, 1927.',
#  'Television became an important home entertainment broadcast medium after World War II, with significant contributions from technology such as the cathode ray tube.',
#  'A thermionic tube or valve performs fundamental electronic functions such as signal amplification and current rectification using thermionic emission of electrons from a heated cathode.',
#  'The diode, the simplest vacuum tube, was invented by John Ambrose Fleming. It consists of a heated electron-emitting cathode and an anode, allowing electrons to flow in one direction from the cathode to the anode.',
#  'Control grids in a thermionic tube allow the current between the cathode and anode to be controlled by the voltage on the grid or grids.',
#  'Thermionic tubes were crucial components in the development of electronic circuits for radio, television, radar, sound recording and reproduction, long-distance telephone networks, and analogue and early digital computers during the first half of the 20th century.',
#  'The invention of semiconductor devices in the 1940s led to the replacement of thermionic tubes. Transistors, which are smaller, cheaper, and more efficient, replaced thermionic tubes starting in the mid-1960s.',
#  'On September 11, 1940, George Stibitz demonstrated remote computing using a teletype. He used a configuration of a centralized computer (mainframe) with remote dumb terminals, a setup that remained popular into the 1970s.',
#  'Paul Baran and Donald Davies started to investigate packet switching technology in the 1960s. Their work led to the emergence of a four-node network on December 5, 1969, constituting the beginnings of the ARPANET, which eventually evolved into the Internet.',
#  'The effective capacity to exchange information worldwide through two-way telecommunication networks grew from 281 petabytes (pB) in 1986 to 471 pB in 1993, 2.2 exabytes (eB) in 2000, and 65 eB in 2007.',
#  'The growth of transmission capacity from 1986 to 2007 equates to two newspaper pages per person per day in 1986 and six entire newspapers per person per day by 2007.',
#  'Telecommunications play an increasingly important role in the world economy. The global telecommunications industry was about a $4.7 trillion sector in 2012.',
#  "The service revenue of the global telecommunications industry was estimated to be $1.5 trillion in 2010, corresponding to 2.4% of the world's gross domestic product (GDP).",
#  'The basic elements of a telecommunication system are a transmitter, a transmission medium, and a receiver.',
#  "In a radio broadcasting station, the transmitter is the station's large power amplifier, and the broadcasting antenna is the interface between the power amplifier and the free space channel.",
#  'A transceiver in telecommunication can work as both the transmitter and the receiver. It contains transmission and receiver electronics that are independent of each other.',
#  'Transceivers need to be carefully designed and built to isolate their high-power circuitry and low-power circuitry to prevent interference.',
#  "'Point-to-point communication' refers to telecommunication between a transmitter and a receiver over fixed lines. 'Broadcast communication' refers to telecommunication through radio broadcasts between a powerful transmitter and multiple sensitive radio receivers.",
#  'Multiplex systems in telecommunication involve multiple transmitters and receivers cooperating and sharing the same physical channel. They offer the advantage of significant cost reduction through the sharing of physical channels.',
#  'Communication signals can be sent by analog signals or digital signals.',
#  'Analog signals vary continuously with respect to the information they carry.',
#  'The key advantage of digital signals over analog signals is their resistance to noise. Information in digital signals remains intact as long as noise does not exceed a certain threshold.',
#  'In analog systems, as noise increases, the signal becomes progressively more degraded but remains usable.',
#  'Digital systems fail catastrophically when noise exceeds their ability to autocorrect.',
#  'The downside of digital transmission of continuous data is the unavoidable addition of quantization noise to the output. Reducing this noise increases the channel bandwidth requirement.',
#  "The two different meanings of the term 'channel' in telecommunications are: 1) The physical medium that carries a signal between the transmitter and the receiver. 2) A subdivision of a transmission medium for sending multiple streams of information simultaneously.",
#  'Examples of physical mediums serving as communication channels are the atmosphere for sound communications, glass optical fibers for optical communications, coaxial cables for communications using voltages and electric currents, and free space for communications using various types of electromagnetic waves.',
#  'Frequency-division multiplexing (FDM) is the concept of dividing a communications medium into channels according to frequencies. Each channel is assigned a separate frequency bandwidth to broadcast signals.',
#  "The alternative method of dividing a communications medium into channels is called 'time-division multiplexing' (TDM). It allocates each sender a recurring time slot for sending messages.",
#  'Communication systems that use a hybrid of TDM and FDM allocate time slots for sending messages within an allocated FDM channel.',
#  'Modulation is the process of shaping a signal to convey information. It can represent a digital message as an analog waveform. Keying techniques like phase-shift keying, frequency-shift keying, and amplitude-shift keying are used for modulation.',
#  "Phase-shift keying (PSK) is a keying technique used in communication systems, such as 'Bluetooth,' to exchange information between devices. Quadrature amplitude modulation (QAM) combines PSK and amplitude-shift keying for high-capacity digital radio communication systems.",
#  'Modulation allows the transmission of low-frequency analog signals at higher frequencies. This is necessary because low-frequency signals cannot be efficiently transmitted over free space. Techniques like amplitude modulation (AM) and frequency modulation (FM) are used to achieve this.',
#  'Modulation offers the advantage of using frequency division multiplexing (FDM), allowing multiple signals to share the same transmission medium by allocating separate frequency bands.',
#  'A telecommunications network is a system of transmitters, receivers, and communication channels that exchange messages between different points.',
#  'In digital communications networks, routers are used to transmit information to the correct user by directing the messages through the network.',
#  'An analog communications network is composed of switches that create connections between multiple users, allowing them to communicate with each other.',
#  'Repeaters are used in telecommunications networks to amplify or regenerate signals transmitted over long distances, counteracting attenuation that can lead to signal degradation.',
#  'Digital systems have the advantage of easier memory storage due to their binary nature, making it simpler to represent information as discrete voltage states.',
#  'Telecommunications has allowed companies to build global business empires, like Amazon.com, and given competitive advantages to retailers like Walmart through better telecommunication infrastructure. Homeowners also use telephones to order home services and communities use mobile phones for better pricing and sales.',
#  'Lars-Hendrik Röller and Leonard Waverman suggested a causal link between good telecommunication infrastructure and economic growth on a macroeconomic scale.',
#  "The 'digital divide' refers to the inequitable access to telecommunication services among different countries, with some having better access to technology and services than others.",
#  'Telecommunication has become increasingly important in social relationships, with technologies like social networking sites, SMS, and the telephone playing significant roles in connecting people, organizing social events, and even courtship.',
#  'Social networking sites have gained popularity as platforms for communication, allowing users to connect, share photos, events, and profiles. They have become important for social interactions, including organizing events and courtship.',
#  'Telecommunication has allowed people to access music and film more conveniently. Through television, people can watch films at home without going to cinemas. Similarly, radio and the Internet have provided easy access to new music without requiring trips to music stores.',
#  'Telecommunication has changed news consumption by allowing people to receive news through television and radio. A 2006 survey found that a majority of Americans preferred television or radio over newspapers for news consumption.',
#  'In 2007, telecommunication had a significant impact on advertising expenditures in the United States, with 58% of advertising spending allocated to media that rely on telecommunication. These media included the Internet, radio, cable TV, syndicated TV, spot TV, network TV, newspapers, magazines, and outdoor advertising.',
#  'The International Telecommunication Regulations established by the ITU are a set of regulations that provide international protection to registered frequencies and address radio regulation issues.',
#  'The digital divide refers to the inequitable access to telecommunication services and technology among various countries around the world.',
#  'Telecommunication has influenced advertising expenditures by contributing to media spending. In 2007, a significant portion (58%) of advertising expenditure in the United States was allocated to media reliant on telecommunication, including the Internet, radio, cable TV, syndicated TV, spot TV, network TV, newspapers, magazines, and outdoor advertising.',
#  'Sales of main consumer telecommunication equipment, such as computers and cell phones, have shown steady growth over the years.',
#  "Telephone networks use switches to establish an electrical connection between callers. The switches determine the connection electronically, and the caller's voice is transformed into an electrical signal for transmission.",
#  'The main advantage of digital broadcasts over traditional analog broadcasts is that they prevent problems such as snowy pictures, ghosting, and distortion caused by noise. Digital signals are reduced to discrete values upon reception, which eliminates the impact of small perturbations and maintains the quality of the output signal.',
#  'The three competing standards for digital television broadcasting are ATSC, DVB, and ISDB. These standards use various audio and video compression methods, such as Dolby Digital AC-3, Advanced Audio Coding, and MPEG-1 Part 3 Layer 2.',
#  'The key difference between HD Radio and Eureka 147 for digital audio broadcasting is that HD Radio uses in-band on-channel transmission, allowing digital information to piggyback on normal AM or FM analog transmissions, while Eureka 147 follows a standard transmission method.',
#  'The United States ended analog television transmission (by all but the very low-power TV stations) on 12 June 2009 after twice delaying the switchover deadline.',
#  'The three standards for broadcasting color TV in analog television are PAL (German designed), NTSC (American designed), and SECAM (French-designed).',
#  'The OSI reference model is a layered approach to computer network communication. It allows protocols to operate independently at different layers of the protocol stack, enabling customization for different network situations while maintaining compatibility between higher-level protocols. This model emerged in 1983 as an attempt to build a universally adopted networking protocol suite.',
#  'Protocols in computer networks define the rules and conventions for communication between computers and routers. They enable standardized communication across different layers of the protocol stack, allowing customization for specific network situations while maintaining compatibility between higher-level protocols.',
#  'The characteristics that distinguish LANs from larger networks include not requiring all the features associated with larger networks, being more cost-effective and efficient, and having advantages of privacy and security. However, lacking a direct Internet connection does not provide assured protection from potential threats.',
#  'Some of the advantages of WANs include privacy and security. WANs are often used by armed forces and intelligence agencies to maintain the security and secrecy of their information.',
#  'In the mid-1980s, communication protocols like AppleTalk, IPX, and NetBIOS emerged to bridge the gaps between the data-link and application layers of the OSI reference model. IPX was dominant in the early 1990s due to its popularity with MS-DOS users.',
#  'The TCP/IP protocols replaced existing local area network technologies as the Internet grew in popularity and its traffic needed to be routed into private networks. Additional technologies like DHCP enabled self-configuration of TCP/IP-based computers within the network.',
#  'For larger networks like WANs, typical data-link protocols include Asynchronous Transfer Mode (ATM) or Multiprotocol Label Switching (MPLS). For LANs, typical data-link protocols are Ethernet and Token Ring. These protocols are simpler and offer medium access control, making them more economical compared to protocols used in larger networks.',
#  'In networking, the distinction between multimode fibers and single-mode fibers lies in their characteristics. Multimode fibers are thicker and cheaper to manufacture devices for, but they have less usable bandwidth and worse attenuation, leading to poorer long-distance performance. Single-mode fibers offer better performance for long-distance communication.',
#  'A telecommunications network is a collection of interconnected nodes that exchange messages through telecommunications links. The links may use circuit switching, message switching, or packet switching technologies.',
#  "In a telecommunications network, there are three planes: the data plane (carries users' traffic), the control plane (carries control information), and the management plane (handles operations and management traffic).",
#  'Some examples of telecommunications networks are computer networks, the Internet, the public switched telephone network (PSTN), the global Telex network, the aeronautical ACARS network, and wireless radio networks of cell phone providers.',
#  'Features that differentiate MANs from LANs or WANs include the network size (between LANs and WANs), ownership by associations or network providers, and the role as a means for sharing resources within the network and providing connections to WANs.',
#  "Edholm's law describes the trend that the bandwidth of telecommunication networks doubles every 18 months. This law is evident in the growth of bandwidth in various networks like the Internet, cellular, wireless and wired LANs, and personal area networks.",
#  'A computer network is a collection of computers connected by communication protocols to share resources using telecommunication technologies, including wired, optical, and wireless methods.',
#  'Nodes in a computer network can be personal computers, servers, networking hardware, or specialized hosts. They have network addresses and hostnames for identification, with hostnames serving as memorable labels.',
#  "Various milestones influenced computer networking's development, including the Bell 101 modem, time-sharing concepts, packet switching by Baran and Davies, ARPANET's establishment, hierarchical routing by Kleinrock, X.25's adoption, Ethernet's description, TCP's specification, and Ethernet's speed advancements.",
#  'Computer networks extend interpersonal communications through technologies like email, instant messaging, online chat, voice and video calls, and video conferencing. They also enable resource sharing and access to shared devices like printers and storage. Networks facilitate sharing files, data, and information among authorized users and support distributed computing.',
#  'A network packet is a formatted unit of data carried by a packet-switched network. It contains control information (such as source and destination addresses, error detection codes) and user data (payload). The packet allows efficient sharing of bandwidth among users and can be queued if the route is not immediately available. Packet networks have a maximum transmission unit (MTU) that limits packet size; longer messages may be fragmented and reassembled upon arrival.',
#  "The topology of a network's interconnections can significantly impact its throughput and reliability. Some network topologies, like bus or star networks, can fail entirely with a single node failure. More interconnections generally lead to greater network robustness, but this can increase installation costs.",
#  'Some common network topologies include bus networks, star networks, ring networks, mesh networks, fully connected networks, and tree networks. The physical layout of nodes may differ from the network topology; for instance, FDDI has a ring topology but a star-like physical layout.',
#  'An overlay network is a virtual network layered on top of an underlying network. It connects nodes with virtual links that may differ from the physical connections of the underlying network. For instance, the Internet is an overlay network built on the telephone network. Overlay networks can improve routing and quality of service without changing all routers.',
#  'Transmission media in computer networking include electrical cable, optical fiber, and free space. Ethernet uses copper and fiber, while wireless LANs use radio waves or infrared signals. Power line communication utilizes power cabling for data transmission.',
#  'Wired computer networking technologies include coaxial cable, twisted pair cabling, and optical fiber. Coaxial cable is used in cable TV and LANs. Twisted pair comes in unshielded and shielded forms for Ethernet. Optical fibers transmit data via light for long high-data-rate runs.',
#  'Wireless network connections are established using radio or electromagnetic communication. Terrestrial microwave and satellites use microwaves. Cellular networks divide areas into regions with low-power transceivers. Wireless LANs use radio waves and spread spectrum. Free-space optical communication uses light. The Interplanetary Internet extends the Internet using radio waves and optics.',
#  'A network interface controller (NIC) connects a computer to network media and processes low-level network data. It has a unique MAC address and helps identify devices on a network.',
#  'A repeater receives and regenerates network signals to extend coverage. It addresses signal degradation over long cable runs. While useful, repeaters introduce a propagation delay that can impact network performance.',
#  'Bridges and switches forward frames to relevant ports, unlike hubs which send frames to all ports. They operate at the data link layer, segment collision domains, and create efficient networks by dividing large congested networks.',
#  'Routers forward packets between networks by processing routing information. They enhance network efficiency and scalability by intelligently directing data.',
#  'Modems convert digital signals to analog for transmission over non-digital mediums or wireless links. They were used for phone lines and are still used for DSL and DOCSIS technology.',
#  'A firewall controls network security and access rules, serving as a barrier between secure internal networks and insecure external networks. It allows actions from recognized sources and blocks unrecognized ones.',
#  'A communication protocol is a set of rules for exchanging information over a network, defining how data is structured, transmitted, and received between devices.',
#  "Communication functions are divided into protocol layers in a stack, leveraging lower layers' services. This layering facilitates modular and efficient communication across devices.",
#  'The TCP/IP model, or Internet protocol suite, is the basis of modern networking. It provides services over unreliable networks and defines addressing, identification, and routing for IPv4 and IPv6.',
#  'The IEEE 802 protocol suite includes standards for local and metropolitan networks, primarily operating at layers 1 and 2. It covers MAC bridging, VLANs, and port-based Network Access Control.',
#  'Ethernet is a technology used in wired LANs, defined by IEEE 802.3 standards. It enables devices to share a communication medium and access it using CSMA/CD.',
#  'IEEE 802.11, or WiFi, is a standard for wireless LANs. It resembles wired Ethernet and allows devices to communicate wirelessly, similar to wired networks.',
#  'SONET and SDH are protocols for transferring digital bit streams over optical fiber. Initially for telephony, they also support ATM frames due to protocol neutrality.',
#  "Asynchronous Transfer Mode (ATM) is a switching technique using fixed-sized cells, distinct from protocols using variable-sized packets or frames. It's versatile for both data and real-time content.",
#  'Cellular standards like GSM and CDMA enable voice and data communication in mobile networks. They use technologies like GSM, CDMA, and UMTS for wireless communication.',
#  'Routing is the process of finding the optimal paths for data packets to travel through a network from a source to a destination.',
#  'Routing protocols guide the forwarding of data packets through intermediate nodes in packet-switched networks, determining optimal paths based on network conditions and addresses.',
#  'Routers, bridges, gateways, firewalls, and switches are network devices involved in routing, directing data packets through the network based on routing protocols.',
#  'Routing tables store route information, including destination addresses, which routing algorithms use to determine the best path for forwarding data packets.',
#  'Routing relies on structured addresses and efficient routing tables, while bridging uses unstructured MAC addresses for forwarding data within local area networks.',
#  'A home area network (HAN) connects digital devices within a home, facilitating communication and sharing of resources like Internet access.',
#  'A storage area network (SAN) offers access to consolidated data storage, allowing servers to access storage devices as if they were locally attached.',
#  'A backbone network connects multiple LANs or subnetworks, providing a high-capacity path for exchanging information between interconnected networks.',
#  'A wide area network (WAN) covers a vast geographic area, connecting locations using diverse transmission media and operating across the physical, data link, and network layers of the OSI model.',
#  'The Internet is a worldwide network of interconnected networks that employs the Internet protocol suite and relies on a vast infrastructure of fiber-optic cables and optical networking.',
#  'Network services are hosted applications that offer functionality for network users or the network itself to operate, such as the World Wide Web, E-mail, printing, and network file sharing.',
#  'Some examples of well-known network services are the World Wide Web, E-mail, DNS (Domain Name System), and DHCP (Dynamic Host Configuration Protocol).',
#  "In computing, 'bandwidth' refers to the rate of data transfer through a communication path. It includes concepts like consumed bandwidth, achieved throughput, and goodput.",
#  'Network delay is the time it takes for data to travel from one communication endpoint to another in a telecommunications network. It includes components like processing, queuing, transmission, and propagation delays.',
#  'Quality of service (QoS) in network performance refers to maintaining specific criteria like throughput, jitter, bit error rate, and latency to ensure consistent and reliable network services.',
#  'Network congestion happens when a link or node is overwhelmed with more data than it can handle, causing a decline in quality of service. This can result in effects like queuing delay, packet loss, and blocked connections.',
#  'Network resilience is the capacity of a network to provide an acceptable level of service despite faults and challenges. It is essential for maintaining network operations during disruptions.',
#  "Network security includes measures to prevent unauthorized access, misuse, or modification of a computer network and its resources. It's crucial for safeguarding data, transactions, and communications from threats.",
#  'End-to-end encryption (E2EE) secures data between two communicating parties, preventing intermediaries from accessing or altering communications. E2EE is used in systems like HTTPS, PGP for email, and OTR for instant messaging.',
#  'SSL (Secure Socket Layer) and TLS (Transport Layer Security) are cryptographic protocols that enhance network security by offering authentication, encryption, and data integrity for secure communication between clients and servers.',
#  'Users and network administrators have distinct perspectives on networks. Users share resources within a workgroup on the same LAN, while Network Administrators maintain network functionality. Communities of interest consist of dispersed users sharing servers and using peer-to-peer technologies.',
#  'Network administrators see networks from physical and logical viewpoints. Physically, they consider geography, cabling, and network elements. Logically, networks or subnets are mapped onto transmission media. In buildings, LAN cables can form subnets using VLAN technology.',
#  'An intranet is a private network managed by an enterprise, accessed only by authorized users. It may not be connected to the Internet. An extranet extends an intranet, enabling secure communication with external parties like business partners or customers.',
#  'From an engineering perspective, the Internet is a network of connected users, enterprises, and content providers served by Internet Service Providers (ISPs). It encompasses subnets, subnet aggregates, and IP address space sharing. The Domain Name System (DNS) converts server names to IP addresses.',
#  'The Internet hosts business-to-business (B2B), business-to-consumer (B2C), and consumer-to-consumer (C2C) communications. Sensitive or financial exchanges are often protected by communication security measures. Virtual Private Network (VPN) technology ensures secure intranet and extranet connections over the Internet.']

# %%
# Initialize the tokenizer
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

# %% [markdown]
# ### **Tokenize the Train Question, Context and Answer**

# %%
# Tokenize questions and contexts
tokenized_questions = tokenizer(
    train_questions,
    train_contexts,
    padding=True,
    truncation=True,
    return_tensors="pt",
    return_attention_mask=True  # Add this line to get attention masks
)

# Tokenize answers
tokenized_answers = tokenizer(
    train_answers,
    padding=True,
    truncation=True,
    return_tensors="pt",
    return_attention_mask=True  # Add this line to get attention masks
)

# %% [markdown]
# # **Multi Head Attention**

# %% [markdown]
# ![Multi Head Attention Layer](https://miro.medium.com/v2/resize:fit:720/format:webp/0*--TCGWYxwASbv2ra.png)

# %% [markdown]
# > #### **Each pair of sets in a sequence have their attention computed by the multi-head attention mechanism. It is made up of various "attention heads" that focus on various facets of the input sequence.**

# %% [markdown]
# > #### **Initializing the module with input parameters and linear transformation layers is done by the MultiHeadAttention function. The attention outputs from all the heads are combined, the input tensor is split up into several heads, and attention scores are calculated. The multi-head self-attention is computed using the forward technique, which enables the model to concentrate on various facets of the input sequence.**

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self, d_model, num_heads):
        super(MultiHeadAttention, self).__init__()
        assert d_model % num_heads == 0, "d_model must be divisible by num_heads"
        
        self.d_model = d_model
        self.num_heads = num_heads
        self.d_k = d_model // num_heads
        
        self.W_q = nn.Linear(d_model, d_model)
        self.W_k = nn.Linear(d_model, d_model)
        self.W_v = nn.Linear(d_model, d_model)
        self.W_o = nn.Linear(d_model, d_model)
        
    def scaled_dot_product_attention(self, Q, K, V, mask = None):
#         print("Mask shape:", mask.shape)
        attn_scores = torch.matmul(Q, K.transpose(-2,-1)) / math.sqrt(self.d_k)
        if mask is not None:
#             print("Attn Scores shape:", attn_scores.shape)
#             print("Mask shape:", mask.shape)
#             print("Mask == 0 shape:", (mask == 0).shape)
            attn_scores = attn_scores.masked_fill(mask == 0, -1e9)
        attn_probs = torch.softmax(attn_scores, dim=-1)
        output = torch.matmul(attn_probs, V)
        return output
    
    def split_heads(self, x):
        batch_size, seq_length, d_model = x.size()
        return x.view(batch_size, seq_length, self.num_heads, self.d_k).transpose(1,2)
    
    def combine_heads(self, x):
        batch_size, _, seq_length, d_k = x.size()
        return x.transpose(1,2).contiguous().view(batch_size, seq_length, self.d_model)
    
    def forward(self, Q, K, V, mask = None):
#         print("Q shape:", Q.shape)
#         print("K shape:", K.shape)
#         print("V shape:", V.shape)
        
        Q = self.split_heads(self.W_q(Q))
        K = self.split_heads(self.W_k(K))
        V = self.split_heads(self.W_v(V))
        
        attn_output = self.scaled_dot_product_attention(Q, K, V, mask)
        output = self.W_o(self.combine_heads(attn_output))
        return output

# %% [markdown]
# # **Position-wise Feed-forward Network**

# %% [markdown]
# > #### **Position-wise feed-forward networks are implemented via the PositionWiseFeedForward class, which extends PyTorch's nn.Module. Two linear transformation layers and a ReLU activation function are the class's initial configurations. The forward method computes the output by consecutively applying these transformations and the activation function. This procedure enables the model to make predictions while taking the position of input elements into account.**

# %%
class PositionWiseFeedForward(nn.Module):
    def __init__(self, d_model, d_ff):
        super(PositionWiseFeedForward, self).__init__()
        self.fc1 = nn.Linear(d_model, d_ff)
        self.fc2 = nn.Linear(d_ff, d_model)
        self.relu = nn.ReLU()
        
    def forward(self, x):
        return self.fc2(self.relu(self.fc1(x)))

# %% [markdown]
# # **Positional Encoding**

# %% [markdown]
# > #### **Positional Encoding is used to inject the position information of each token in the input sequence. It uses sine and cosine functions of different frequencies to generate the positional encoding.**

# %% [markdown]
# > #### **With the input parameters d_model and max_seq_length, the PositionalEncoding class creates a tensor to hold the positional encoding data. Based on the scaling factor div_term, the class computes sine and cosine values for even and odd indices, respectively. The model is able to capture the positional information of the input sequence thanks to the forward technique, which computes the positional encoding by adding the stored positional encoding values to the input tensor.**

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_seq_length):
        super(PositionalEncoding, self).__init__()
        
        pe = torch.zeros(max_seq_length, d_model)
        position = torch.arange(0, max_seq_length, dtype = torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * -(math.log(10000.0) / d_model))
        
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        
        self.register_buffer('pe', pe.unsqueeze(0))
        
    def forward(self, x):
        return x + self.pe[:, :x.size(1)]

# %% [markdown]
# # **Encoding Layer**

# %% [markdown]
# ![Encoding Layer](https://miro.medium.com/v2/resize:fit:552/format:webp/0*bPKV4ekQr9ZjYkWJ.png)

# %% [markdown]
# > #### **An Encoder layer consists of a Multi-Head Attention layer, a Position-wise Feed-Forward layer, and two Layer Normalization layers.**

# %% [markdown]
# > #### **Initialization parameters and components for the MultiHeadAttention module, PositionWiseFeedForward module, two layer normalization modules, and dropout layer are provided to the EncoderLayer class. By using self-attention, adding the attention output to the input tensor, and normalizing the result, the forward method computes the encoder layer output. Prior to providing the processed tensor, it computes the position-wise feed-forward output, mixes it with the normalized self-attention output, and then normalizes the final result.**

# %%
class EncoderLayer(nn.Module):
    def __init__(self, d_model, num_heads, d_ff, dropout):
        super(EncoderLayer, self).__init__()
        self.self_attn = MultiHeadAttention(d_model, num_heads)
        self.feed_forward = PositionWiseFeedForward(d_model, d_ff)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, x, mask):
#         print("Input x shape:", x.shape)
        
        # For the self-attention mechanism, queries, keys, and values all come from the same input x
        attn_output = self.self_attn(x, x, x, attention_mask)  # Use the modified attention mask
        x = self.norm1(x + self.dropout(attn_output))
        ff_output = self.feed_forward(x)
        x = self.norm2(x + self.dropout(ff_output))
        return x

# %% [markdown]
# # **Decoding Layer**

# %% [markdown]
# ![Decoder Layer](https://miro.medium.com/v2/resize:fit:552/format:webp/0*SPZgT4k8GQi37H__.png)

# %% [markdown]
# > #### **Two Multi-Head Attention layers, a Position-wise Feed-Forward layer, and three Layer Normalization levels make up a decoder layer.**

# %% [markdown]
# > #### **The PositionWiseFeedForward module, three layer normalization modules, a dropout layer, and MultiHeadAttention modules for masked self- and cross-attention are some of the input parameters and components that the DecoderLayer initializes with.**

# %%
class DecoderLayer(nn.Module):
    def __init__(self, d_model, num_heads, d_ff, dropout):
        super(DecoderLayer, self).__init__()
        self.self_attn = MultiHeadAttention(d_model, num_heads)
        self.cross_attn = MultiHeadAttention(d_model, num_heads)
        self.feed_forward = PositionWiseFeedForward(d_model, d_ff)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.norm3 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, x, enc_output, src_mask, tgt_mask):
        # For self-attention in the decoder, queries, keys, and values all come from the same input x
        attn_output = self.self_attn(x, x, x, tgt_mask)
        x = self.norm1(x + self.dropout(attn_output))
        
        # For cross-attention in the decoder, queries come from x, and keys and values come from the encoder output enc_output
        cross_attn_output = self.cross_attn(x, enc_output, enc_output, src_mask)
        x = self.norm2(x + self.dropout(cross_attn_output))
        
        ff_output = self.feed_forward(x)
        x = self.norm3(x + self.dropout(ff_output))
        return x

# %% [markdown]
# # **Q&A Transformer Model**

# %% [markdown]
# ![Q&A Transformer Model](https://miro.medium.com/v2/resize:fit:640/format:webp/0*ljYs7oOlKC71SzSr.png)

# %% [markdown]
# 1. `nn.Module` Inheritance:
#    The `QATransformer` class inherits from `nn.Module`, which is the base class for all PyTorch modules.
#
# 2. Initialization (`__init__`):
#    The constructor initializes the various components of the transformer model.
#
#    - `self.embedding`: An embedding layer that converts input token IDs into dense vectors of size `d_model`.
#    - `self.positional_encoding`: A positional encoding layer that adds positional information to the input embeddings.
#    - `self.encoder_layers`: A list of `num_layers` `EncoderLayer` instances, which make up the encoder stack.
#    - `self.fc`: A linear layer that projects the final encoder output to the vocabulary size, making predictions for each token in the vocabulary.
#    - `self.dropout`: A dropout layer for regularization.
#
# 3. Forward Pass (`forward`):
#    The `forward` method defines the forward pass through the transformer model.
#
#    - `input_ids`: Token IDs of the input sequence.
#    - `attention_mask`: A mask to specify which positions should receive attention and which shouldn't. This mask helps the model ignore padding tokens.
#
#    Inside the forward pass:
#
#    - The input token IDs are first embedded using the embedding layer and then passed through the positional encoding layer.
#    - The resulting embeddings are then passed through the stack of `num_layers` `EncoderLayer` instances, using the provided `attention_mask`.
#    - The final output of the encoder stack is passed through the linear layer (`self.fc`) to get the predicted token scores for each position in the sequence.
#
# 4. `EncoderLayer`:
#    The `EncoderLayer` class is expected to be defined elsewhere in your code and is used within the `QATransformer` class. It likely includes sublayers such as multi-head self-attention and feedforward neural networks.
#
# 5. `PositionalEncoding`:
#    The `PositionalEncoding` class is expected to be defined elsewhere in your code and is used to add positional information to the input embeddings. It helps the model understand the order of the tokens in the sequence.
#
# > #### **Overall, the code defines the structure of a transformer-based QA model and encapsulates the core logic needed for processing input sequences, applying attention mechanisms, and generating predictions.**

# %%
class QATransformer(nn.Module):
    def __init__(self, vocab_size, d_model, num_heads, num_layers, d_ff, max_seq_length, dropout):
        super(QATransformer, self).__init__()
        self.embedding = nn.Embedding(vocab_size, d_model)
        self.positional_encoding = PositionalEncoding(d_model, max_seq_length)
        
        self.encoder_layers = nn.ModuleList([EncoderLayer(d_model, num_heads, d_ff, dropout) for _ in range(num_layers)])
        self.fc = nn.Linear(d_model, vocab_size)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, input_ids, attention_mask=None):  # Add attention_mask parameter
        input_embedded = self.dropout(self.positional_encoding(self.embedding(input_ids)))
        enc_output = input_embedded
        for enc_layer in self.encoder_layers:
            enc_output  = enc_layer(enc_output, attention_mask)  # Use the provided attention_mask

        output = self.fc(enc_output)
        return output

# %% [markdown]
# # **Hyperparameters**

# %% [markdown]
# - Source (input) vocabulary size: 5000
# - Target (output) vocabulary size: 5000
# - Model dimension (d_model): 512
# - Number of attention heads (num_heads): 8
# - Number of encoder layers (num_layers): 6
# - Feedforward dimension (d_ff): 2048
# - Maximum sequence length (max_seq_length): 500
# - Dropout rate: 0.1
#
# > #### **With these hyperparameters, you can instantiate the `QATransformer` class and create your QA model.**

# %%
src_vocab_size = 5000
tgt_vocab_size = 5000
d_model = 512
num_heads = 8
num_layers = 6
d_ff = 2048
max_seq_length  = 500
dropout = 0.1

# %% [markdown]
# # **Create a Q&A Transformer Model**

# %% [markdown]
# > #### **creating an instance of the QATransformer model using the hyperparameters we've defined**

# %%
# Create a QATransformer model
# qa_transformer = QATransformer(tokenizer.vocab_size, d_model, num_heads, num_layers, d_ff, max_seq_length, dropout)

# qa_transformer.to(device)

# %%
model_path = "/kaggle/working/model_final_1"
qa_transformer = QATransformer(tokenizer.vocab_size, d_model, num_heads, num_layers, d_ff, max_seq_length, dropout)
qa_transformer.load_state_dict(torch.load(model_path))
qa_transformer.eval()
# Out:
# QATransformer(
#   (embedding): Embedding(30522, 512)
#   (positional_encoding): PositionalEncoding()
#   (encoder_layers): ModuleList(
#     (0-5): 6 x EncoderLayer(
#       (self_attn): MultiHeadAttention(
#         (W_q): Linear(in_features=512, out_features=512, bias=True)
#         (W_k): Linear(in_features=512, out_features=512, bias=True)
#         (W_v): Linear(in_features=512, out_features=512, bias=True)
#         (W_o): Linear(in_features=512, out_features=512, bias=True)
#       )
#       (feed_forward): PositionWiseFeedForward(
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (relu): ReLU()
#       )
#       (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (fc): Linear(in_features=512, out_features=30522, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
# )

# %% [markdown]
# > **We'll set up the loss criterion and optimizer for training your QA Transformer model:**
#
# 1. **Loss Criterion (`nn.CrossEntropyLoss`)**
#    - We're using the `nn.CrossEntropyLoss` function as our loss criterion. This loss function combines a softmax operation with the negative log likelihood loss. It's commonly used for multi-class classification tasks where each example can belong to only one class.
#    - The `ignore_index` parameter is set to 0. This parameter is used to ignore padding tokens during loss calculation. In this case, it seems that token ID 0 represents padding tokens, so they will be ignored when computing the loss.
#
# 2. **Optimizer (`optim.Adam`)**
#    - We're using the Adam optimizer for training your model's parameters. Adam is an adaptive learning rate optimization algorithm that adjusts the learning rate for each parameter.
#    - The `qa_transformer.parameters()` call provides the list of trainable parameters in our`qa_transformer` model to the optimizer.
#    - `lr` sets the initial learning rate for the optimizer.
#    - `betas` are the coefficients used for computing running averages of gradient and its square.
#    - `eps` is a small value added to the denominator for numerical stability.
#
# > **These configurations are appropriate for training a transformer model for a QA task. After setting up the loss criterion and optimizer, we can proceed with the training loop where we'll iterate through your training data, compute gradients, and update model parameters to minimize the loss.**

# %%
criterion = nn.CrossEntropyLoss(ignore_index=0)
optimizer = optim.Adam(qa_transformer.parameters(), lr=0.0001, betas=(0.9, 0.98), eps=1e-9)

# %% [markdown]
# # **Q&A Training**

# %%
qa_transformer.train()
# Out:
# QATransformer(
#   (embedding): Embedding(30522, 512)
#   (positional_encoding): PositionalEncoding()
#   (encoder_layers): ModuleList(
#     (0-5): 6 x EncoderLayer(
#       (self_attn): MultiHeadAttention(
#         (W_q): Linear(in_features=512, out_features=512, bias=True)
#         (W_k): Linear(in_features=512, out_features=512, bias=True)
#         (W_v): Linear(in_features=512, out_features=512, bias=True)
#         (W_o): Linear(in_features=512, out_features=512, bias=True)
#       )
#       (feed_forward): PositionWiseFeedForward(
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (relu): ReLU()
#       )
#       (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (fc): Linear(in_features=512, out_features=30522, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
# )

# %%
# input_ids = tokenized_questions["input_ids"].to(device)
# attention_mask = tokenized_questions["attention_mask"].unsqueeze(1).unsqueeze(2).to(device)

# These input_ids and attention_mask are for the Train Dataset
# input_ids = tokenized_questions["input_ids"]
# attention_mask = tokenized_questions["attention_mask"].unsqueeze(1).unsqueeze(2)

# %%
print("Input IDs shape:", tokenized_questions["input_ids"].shape)
print("Attention Mask shape:", tokenized_questions["attention_mask"].shape)
# Out:
# Input IDs shape: torch.Size([137, 386])
# Attention Mask shape: torch.Size([137, 386])

# %%
# Save the trained model
model_save_path = "/kaggle/working/model"

# %% [markdown]
# ## **Start the Training**

# %%
for epoch in range(1):
    optimizer.zero_grad()

    # Modify the attention mask right before passing it to the model
    attention_mask = tokenized_questions["attention_mask"].unsqueeze(1).unsqueeze(2)
    attention_mask = attention_mask.to(dtype=next(qa_transformer.parameters()).dtype)

    output = qa_transformer(input_ids=tokenized_questions["input_ids"], attention_mask=attention_mask)
    
    # Flatten the output and target tensors, excluding the padded tokens
    output_flat = output.view(-1, tokenizer.vocab_size)
    target_flat = tokenized_answers["input_ids"].contiguous().view(-1)
    mask = (target_flat != tokenizer.pad_token_id)
    non_padded_indices = mask.nonzero().squeeze()  # Get indices of non-padded tokens
    
#     print("Output flat shape:", output_flat.shape)
#     print("Target flat shape:", target_flat.shape)
#     print("Mask shape:", mask.shape)
    
    loss = criterion(output_flat[non_padded_indices], target_flat[non_padded_indices])
    
    # Calculate the loss using only the non-padded tokens
#     loss = criterion(output_flat[mask], target_flat[mask])
    loss.backward()
    optimizer.step()
    torch.save(qa_transformer.state_dict(), model_save_path)
    print(f"Trained model saved to {model_save_path}")
    print(f"Epoch: {epoch+1}, Loss: {loss.item()}")
# Out:
# Trained model saved to /kaggle/working/model
# Epoch: 1, Loss: 0.2824430763721466

# %% [markdown]
# # **Save the Model**

# %%
# Save the trained model
model_save_path_final = "/kaggle/working/model_final_1"
torch.save(qa_transformer.state_dict(), model_save_path_final)
print(f"Trained model saved to {model_save_path_final}")
# Out:
# Trained model saved to /kaggle/working/model_final_1

# %%
# # Inference using the model
# with torch.no_grad():
#     output = qa_transformer(input_ids=tokenized_questions["input_ids"], attention_mask=attention_mask)

# %% [markdown]
# ## **Inference Using the Model (Test Dataset)**

# %%
# Tokenize questions and contexts for Test Dataset
tokenized_questions_test = tokenizer(
    test_questions,
    test_contexts,
    padding=True,
    truncation=True,
    return_tensors="pt",
    return_attention_mask=True  # Add this line to get attention masks
)

# Tokenize answers for Test Dataset
tokenized_answers_test = tokenizer(
    test_answers,
    padding=True,
    truncation=True,
    return_tensors="pt",
    return_attention_mask=True  # Add this line to get attention masks
)

# %%
print("Input IDs shape:", tokenized_questions_test["input_ids"].shape)
print("Attention Mask shape:", tokenized_questions_test["attention_mask"].shape)
# Out:
# Input IDs shape: torch.Size([43, 257])
# Attention Mask shape: torch.Size([43, 257])

# %%
# These input_ids and attention_mask are for the Test Dataset
# input_ids_test = tokenized_questions_test["input_ids"]
# attention_mask_test = tokenized_questions_test["attention_mask"].unsqueeze(1).unsqueeze(2)

# %% [markdown]
# > **We're performing inference using the trained QA Transformer model. Let's break down the code snippet:**
#
# 1. **Inference Block (`with torch.no_grad():`)**
#    - This context manager is used to ensure that no gradients are computed during inference, which helps save memory and processing time since gradients aren't needed for inference.
#
# 2. **Model Inference**
#    - We're passing `input_ids` and `attention_mask` to the `qa_transformer` model to generate predictions.
#    - `input_ids` likely contains the token IDs of the input sequence you want to perform QA on.
#    - `attention_mask` is used to mask out padding tokens so that the model doesn't attend to them during inference.
#    - The `qa_transformer` model computes predictions for each token in the input sequence.
#
# > **After this code block, the `output` tensor contains the model's predictions for each position in the sequence.**

# %%
# Modify the attention mask right before passing it to the model
attention_mask = tokenized_questions_test["attention_mask"].unsqueeze(1).unsqueeze(2)
attention_mask = attention_mask.to(dtype=next(qa_transformer.parameters()).dtype)
with torch.no_grad():
    test_output = qa_transformer(input_ids=tokenized_questions_test["input_ids"], attention_mask=attention_mask)

# %%
# Convert model output to answer tokens
predicted_answer_tokens_test = torch.argmax(test_output, dim=-1)

# %%
# Decode answer tokens
predicted_answers_test = []

# %%
for answer_tokens in predicted_answer_tokens_test:
    answer = tokenizer.decode(answer_tokens, skip_special_tokens=True)
    predicted_answers_test.append(answer)

# %%
# Print predicted answers
for question, predicted_answer in zip(train_questions, predicted_answers_test):
    print(f"Question: {question}")
    print(f"Predicted Answer: {predicted_answer}")
    print("=" * 50)
# Out:
# Question: How does the Lempel-Ziv algorithm improve compression efficiency?
# Predicted Answer: it was data and, algorithms radio like of in allowing,, it call adjusting, communication communication information digital, voice different digital in, a it for communication and communication about and and ar and management it,,,. structured,,, dh.,.,, congestion, by telecommunication.. communication.....,.,,. routing routing,, and and..ging uses,,, ) communication..... over,, while.. - telephone, long. digital, computers 4 and,. horns,,. providers providers... path,,.,,.,. it it.,,, and and,.. service..,,
# ==================================================
# Question: What is the alternative method of dividing a communications medium into channels?
# Predicted Answer: over amplitude it. multiple. they to data. communication in a, or they analog three by it adjusting,, or over'sequences'wave, modulation used. databand, other or communication and on or they over technology of and, for digital a telecommunication conventions,. and and.,,, congestion telecommunication telecommunication communication communication.. telephone technology technology a communication communication communication wired in for and and components components for communication. crucial.. circuits. like it packet,,, and and transmission transmission. it analogue voice,. communication over analog.... digital. analog analog.. speed.. phone analog communication. communication communication.. communication communication. communication signals digital digital digital communication communication. a a communication like in a a communication.
# ==================================================
# Question: What advantage does modulation offer in terms of frequency division multiplexing (FDM)?
# Predicted Answer: itizes voice calls by for radio patented amplitude voice alexander communication. communication they, and. signals for callse and outdoor and its in, frequency voice utilize it.,. they capability voice different and and wheat practicals for and quicker communication channels a restore.s data compression mail,, and standardized over, for s different protocol data wheat practical and for by communication lt. calls, it in concepts ands technology. a and and and and and betweens,, and and and and and,s and and for for,, and and and and andss audio. various and andsss networks and and, and... and ands various various applications applications analog networking and and and and a a, a transmission establishment,, hierarchical voice and and and, transmission they preferredsss ands ands ownership, and or ins, and and and as mediumssss.. and and ands phone and and and they theys, and andss technology technologyss and and and networking...ss and and and and.... ands,...,, and and and and... and and and and...,, and
# ==================================================
# Question: What is a modem?
# Predicted Answer: it was established it of essential a serversized and essential entertainment.. handles various it for news for.. '., voice. used., s it communication voice different communication. for limited of interference essential rules data data restore computer. specific, for and antenna. communication ), over, a essential while different network ande while networks for networks. networks method rules.sss (,..,,,. lans.... like 147,,..,. digital..., for over,,, while transmission,,.. analogue voice., using. communication,....,... over for....l dsl..... a various types, digital.. it communication communication.. for like,, computer. for.,,
# ==================================================
# Question: What is the difference between 4G and 5G?
# Predicted Answer: it over of., networks form 4g it in, it frequency of an for digital entertainment and. for data frequency. for to leonard. this some mail calls a digital and'for source a communication computer,, systems and transmitted. increases.,,, and and, of and networks.,, networks..... for. and routing, of of and and and for... like like,,,, and networks..s, and networks...... and for various. like like, and, while... transmission of. it for digital, of. over of and and.,. communication communication using. technologies for and and and.l communication for. using,, and communication communication.... a digital.. it of a and content and it it,,
# ==================================================
# Question: What are the two ways in which communication signals can be sent?
# Predicted Answer: . advantage, allowing, telephone,iv alexanderiv, were telephone it its to access its modulation is calls specific for denote entertainment, communication '.'traffic used digital communication some communication it between calls. and forder,, were and digital communication using transmission communication communication information. business tob and communication., and.,,,, telecommunication 18 and and.. transmission and and. 3 wired and, and speed for speed. slow postal mail various enable and communication communication communications over networks for. this,, various.,,,, bar and surgery.. for transmission transmission.'for digital transmission.'analog analog and.. and different transmission, digital digital.. 4, and and.. speed,, for....,, lines and. signals.... and communication communication free space,, for for, digital digital... a communication for communication modulation networks by. communication communication networks call and
# ==================================================
# Question: When did television become an important home entertainment broadcast medium, and what technology played a significant role in its development?
# Predicted Answer: was established of and exchanging servers binary radio. in lille, - exchanging sequences, use,s exchanging ensures adaptings it of pass digital, sequences some, ands other a channels pass, operations pass by a, stands frequencies systems,. simpler data term, stands digital over and.. calls systems over receive for 4 network communications. extensive a, and extensive system transmission stands,, standsder digital antenna exchanging internet, for wired, systems antenna forward, detect for, and, calls sensitivedu different. broadcasting systems forward efficients communication and to. improved allowed for can over ham amazon. transmission it it allowing by, it is is it amazon. transmission.. it. an, allowed specific is companies is,. restore use. networkss allowed.... ) an.. allowed italian. of. and informationuting other for telecommunications networks and.. is, caused a restore networkss a ( of, access to and vol and,s data modulation ensures is it to networks modulationep. service datas is., networks communication evolution like
# ==================================================
# Question: Explain the process of quantization in analog-to-digital conversion.
# Predicted Answer: alteringizes voice it, setup servers lt storage 4g roman setup and calls practical. can.,, s communication attached shiftsg'',. for it. it 0, ',. communication'management provides and it employedpressc. for in data communication, for,. remains - data companiesrs place ) voltage routing often communication cheaper network, communication like. communication,. it telephone technology.. a and various and. between, forward forward and and and for computer networks. it for a,,, communications and and for,,,,.,, and and a transmission,.....gyback various various applications it networks radar and and and eureka... transmission transmission transmission. it voice.. mode transmission transmission. data telephone telephone networks... different different.,. to. 4 4 as as. a speedss.., and transmission transmission phone,,, they - like ds microwave.,sis technology.,, and transmission... vast and, transmission and...,, communication...,, signaling, and..,.... messaging.ch,,
# ==================================================
# Question: When did the United States end analog television transmission?
# Predicted Answer: it was amplitude it the, radios binary. ( aized for their process, radio'for. news ( digital ( allows. and over it communication for, a march for data convert,, digital and. and (, a (, over over vol. data,,,,, received, calls data processing,, computer telecommunication networks like like conversion communication computer networks it transmission technology technology a a a various of communication communication internet,,,,, wired computer and personal components capabilities, while digital like like,,,, communication, distortionsss computer communication computer networks, crucial networks..,. a.. it like over,,,,,.. communities telephone networks,, analogue voice. digital, using communication communication overbeats,. data.., digital digital while 4 communication,ss. links,, and technologies like over over,ss digital like for of,,s technology, a,,,..., a various,, digital,. systems,,, like like,,,,,, providers, a services, a a secure inter,,
# ==================================================
# Question: What is the role of a home area network (HAN)?
# Predicted Answer: revolutionizes voice calls it it a radio digital access 4 callsecbook a of digital quicker for, and various communication. it for this it and for it as sequencesband and.,. in over over and, services, as transmission voice. information and specific,. and,. that that that analog. radio radio technology... of of like... between lan networks networks. for capabilities.. systems smartphone communications for audio. networks..s communication band channels...... of..... technologies transmissions, while... transmission transmission,.., transmission.. overs technologies and.... it digital digital digital. transmission transmission.sss using using. transmission transmission transmission of of ofss they ds for of... technology.. currents. and. be. types. digital.... it... a of networks service of.... transmission,
# ==================================================
# Question: How does the automatic repeat request (ARQ) method protect against errors?
# Predicted Answer: . amplitude it using allowing in transmission, datate deco communication and and modulation is it for for transmission.,der and,.. capability communication signal users can it information for communication communication channel feasibleder and communication different transmission,ing voice 0,, over encoded. devices. and calls a rate,, data'it. communication 0 and rate it communication,.. services needed, andg and older networks, data data networks., using. area,, while transmit and audio allowing different., users communication. to wave...'lan like can and share. satellite, and and to. servicesing ( while. words voice, transmission. use telephone and three..ity, of digital digital systems and, analog converted converted for.. links transmission they transmission transmission phone and and and, theyutingl..., and and.. variouss and transmission and., communication of. a abation and and. like, and communication, it
# ==================================================
# Question: What is the key advantage of digital signals over analog signals?
# Predicted Answer: remained,. spot,aging servers use 4, in.,. analog for. planes, communication,drik.. roman specific can operations transmit business noise, it, - military,,,, convey.,,,, received flying.s analog analog - digital conversion digital,. radio,,, variouss digital these wired wired 2 for, and and,,, slow systems inacc for, audio createc.s, digital digital networks - transmission,, for. digital. circuits for....,,,,,,,, transmission establishment. long,,,. overs,, reliability,, digital radio systems systems transmission phone, digital,,. transmission for for phone and,, radiol wireless using radio hilltop technology, networking be be types transmission transmission.. it have have.,, and, online service.,,.. it,,,
# ==================================================
# Question: How are communication protocols organized in a protocol stack?
# Predicted Answer: it, it,,,,s data.,, in,, forc communication path, for for conversion for datas. for adapt to, digital of communication it, digital, and, satellite's and increases. electrical, increases,. for antenna. communication,. remains this transmit,,, telecommunication networks,,, networks...., routing,,,,, and and,,,,,ging,,,,,...,,,, networks,.... circuits,,. it,,,,,,.,. networks,. it.,,.. 25 over analog and...., digital digital.,,..., and and. networks,,,,,...,, transmission,.,s have.., and and and and..,..,,,
# ==================================================
# Question: Why is analog-to-digital conversion necessary for analog signals?
# Predicted Answer: it over established sampling, servers digital 4. sampling, servers was ltbook rules using for. its amplitude communication to call over over used, business convert, conversion over communication subsequently, communication as of. for, different for as for digital it. using,., and received andss,,,,, networks communication communication communication,,.. various various communication.. wired wired relies lan and for for,, such brs smartphones,,, various..s networks. mode. various computer, sound while, for telephone networks. it it for servers digital.. overs and technology.s,,, signals..,, providers....sss. and over. and ands and radio likel.. usings, communication...s, digital signals suchss and and and, service.,,
# ==================================================
# Question: What is the principle behind time-division multiplexing (TDM)?
# Predicted Answer: it data it it, data receive but an networks, and radio frequency telecommunications in data. and communication has networks communication and use digital. their voltage,, digital for and'information their. voice, and and as to their which voice, and and and. different technology mail or a, wheat data network communication, satellites communication,, concepts..., of and,, networks...,, systems like provides or,,s of can..s, communication over,,.. of,. it it and,,, it., transmission a, technologies.,,, systems systems over. digital transmission. analog analogs, like ds of using,,s,, and communication be. digital digital digital it systems as and networks work of of of of it it,,,
# ==================================================
# Question: What is a computer network?
# Predicted Answer: over established between and it. maintainings binary data over digital communication of radioized important '. communication for and it. for. to useds amplitude it % portion business.s stands. burst transmission practical for networks communication communication mail, analog computing for sensitive channels antenna for source voicee communication digital noise.,, voice simpler,, calls by digital. efficient. 4 amplitude radio communication voice can network 2 spot servers which. 2s like of voice voice of detect for., digital systems postal system,,,. over.s,,,,, networks - a analogue voice overs networks..,,. using it digital over,,,... for microwave usings,., communication communication.., transmission transmission signals, it of like. a,,ss providers service a. it,,
# ==================================================
# Question: What is the purpose of a storage area network (SAN)?
# Predicted Answer: .. specific communication and to modulation in it for calls radio is or specific communication adjusting conversion. thiss,. is with specific communications data data b the signals. ( a -., voice and rules as -, specific communications over it over calls it. computing over communication communications digital communications to specific communication digital while efficient, distances transmission, and. specifics to., over. communication transmission practical conducted and wave compression, years like for companies transmission.. empires.s and andrmi.. signals for various like. likeoca and three recording, long - telephone,, and analogue voice digital,,, oversss, 20th.,, digital digital digital. and and over as communication digital,s. sound. and digitals phone lines.., radiol ds and..... and and and space... communications various types and and waves..sss of and systems,, and and, and email using and and andl and and
# ==================================================
# Question: What is network congestion and how does it affect networks?
# Predicted Answer: .izes. of for, networks servers radio in of fors in entertainment and,. wave and digital adjusting'for for for.''. shifts. to over communication'' it of protocol, network, transmission feasible like.q communication, bits,,...,,,, received transmission.., networks excel, it networks networks it., networks...... networks of..,,, wired wired, for transmission and and, for... networksid,,,..,... communication, networks networks.......,,,,,,,,,.... transmission.... for..,, transmission.. over over,,....., digital.. for providers.....s.. optical for,...., networks............ a vast, transmission digital...... communication communication communication.,.,,,,, social......,,,
# ==================================================
# Question: What are the benefits of using SIP in telephony?
# Predicted Answer: . advantage data it vice various it, radio binary, users simpler it network modulation is it is,. is, for is andlessly users'of in adapt to and it. of employ communication communication of and of in for. interference,der business., employ signal over for television,.. frequencies to companies it transmit., but a while.. data data through network, over.c.s from. and important route.. an.. a networks. an.s situations. forg for they for information. medium communication communication essential in reverse communication.., and usersming... bits technique adding,, bits bits. a four. bit transmission transmission. code words contain seven,,,. information bits and bits redundant.... bits bits digital digital maintain. parity. communication converted bit... linksming converted corrects single single channel error and............... a and transmission transmission.... communication communication... communication communication and and....... communication it....
# ==================================================
# Question: What is a wide area network (WAN) and how does it function?
# Predicted Answer: . challenges le due as their binary nature, it in a systems mode radio represent antenna information as discrete voltage states, it and capability digital it voltage to to advantage., some business between vol of it for systems source and for as for transmission. it., for voice digital - expenditures information for it,s, systems, it communication networks a it. networks extensive its to, frequency.. of for various channels. a systems forwardg wired and voice lans and for for for,, system system system for,,,,, ) ),s,ss a a carrier wave, represent, mode two two frequencies are used,, for'' and,, for for''sk,,, hierarchical voice voiceband,, transmit transmit data over and networks,,, digital digital for,, as as lan, a for for for providing,, transmission. for for lines,,,.,. microwave as,sis technology. currents,, two space.. signalss, digital.., communication communication a transceiver and, work work as both and and receiver. it. it,,
# ==================================================
# Question: When and where were the first commercial telephone services set up by the Bell Telephone Company?
# Predicted Answer: advantage established it of for storage binary 4 path vol it their networks data this adapt, modulation entertainment sequences. communication for and for it sequences it digital of for it a transmission of challenges.. vol and, vol encoded anddu. modulation of which voice,.,..,.ization,. networks networks networksncy........ networks.... of of wired for. networks and and of... like postal of.....,.. networks.......... like networks,,,,... networks..., transmission.. overs networks.... digital... 4 provides... speed ands...g phone...... for.............. types transmission digital.......... of networks providers networks computer.. of. for...,,
# ==================================================
# Question: What was the purpose of chains of beacons used on hilltops in the Middle Ages?
# Predicted Answer: it established it satellites and servers storage their lt voice receiver it enhanced. for essential practical conducted,. and to for,lessly calls., data and of communication of like, and over as a communication analog of communication. calls analog of and tv increases, to,, magazines and networks term and,,, a quicker, for a a route a standardized between, practical empires data calls into communication a while, computing,. it digital networks forward data for.,, systems like postal and laptop,s... variousss communication computer band networks,.... various. various like like. networks computer while networks networks. transmission of networks.. voice,, transmission.. modems,. networks analog.... digital for phone of and and, still cables ds communication communication using, and currents and and communication... a analogs signals.. such.. it have of communication and and and computer. networks. and...,
# ==================================================
# Question: What is the process of analog-to-digital conversion?
# Predicted Answer: it challenges setup calls voice, it radio lt in, modulation, in radio code wheat an calls users telephone., and mail ( carries communication trafficlessly. over.. it's and it and communicationman. voice for sequences voice and for mail communication frequency conventions voice a, : information for :,.. of are voice calls be, of over. for communication lt various enabling in and and voicepress users and communication and to.press path telephone. tv over conventions. and for. an and to or a between conventions durationman systems eureka sequences and over and over.'mail communication communication frequency. telephonermi a channel perspectives telecommunication.... electronic ( various applications it it over and and and and it recurring. transmission transmission telephone.. voice voice voice communication mode.. over telephone telephone telephone,... transmission digital analog signals. analog analog over transmission transmissionss wireless transmission phone analog and and analog ds ds communication communication.sis technology technology communication communication free... analog analog transmission transmission and... it it communication. a communicationiver applications online tel work communication communication of and and advantages.. it, and transmission
# ==================================================
# Question: What does the term 'bandwidth' refer to in computing?
# Predicted Answer: , data easier of transmissioning, lars, digit, for a a their is. lars for, of. dutch'systems for, it they, a, roman ensures data communication for voice it deco,, for redundant,,, transmission. if if of,, of of of prices configuration configuration and..,, of analog analog like conversion bandwidth, of. of wave. a a of bandwidth of of for azation, and a of wired and of transmission. a for for a a a a a mail is a of radio of of forward,, and. crucial,.. of a of some like of of computer computer computer and another. a of of of a a it for for for transmission transmission of. information over of and and of a a a transmission it digital.. of of a a.. speed and for a... transmission for a analog a a. they networks for each a using radio and and.ncy forward networking networking. communications a a a array transmission digital. perspective a a a a it it of of of. a a aiver, like a service. a a of networks. a it it contains, and
# ==================================================
# Question: Give examples of physical mediums that serve as communication channels.
# Predicted Answer: it over easier,, use tos alexander,,, approved and and 3 for digital. s entertainment for stands. this, communication it communication it and and, share voice communication and. and communication,,.,, and and communication,,,,,,, and analog like like consumed, communication.,ss. various various communication communication.,,,, and, and, and and communication,,, likess,..ss, communication.,...s and. ),. over over,,,, for a a transmission transmission,. for,,,.. telephones,,, description,, digital..,, and communication communication.,ss. and and for lines,,, they. communication.......,...,,,,...,, have communication.., and and and.,,...,,,
# ==================================================
# Question: What are the three competing standards for digital television broadcasting?
# Predicted Answer: challenges employ to. serverss their like important ) digitized and and to reverse over for medium conversion end,. frequency wheats to to sequences suggested can to communicationband - or for of multiple, by., communication, itder communication,. and'over receives.. it distances communication over calls 4 amplitude dutch established to lt ors. persian networks communication this.s 4 amplitude includesg for. lan.,, and and 2,,, and and for.. radio smartphone ands...ssss.,,,.... for for,... and transmissions and, another. it long, it in voice voice.,,... telephoness...,,, signals signals. providers, as as...ss wireless..s were phone for lines,, and they for for....... currents and and. space., for for,, digital such communications. communications,s have.,,,,, and, email,, and ot for messaging.,,
# ==================================================
# Question: What types of communications are common over the Internet?
# Predicted Answer: it was of it spot, of binary shifts it data they they and radio represent, for analog users. it advertising like. systems.'it. used. in communication 2007 for and and systems and and transmission employed wheat can well a, for in communication the,, it and for to their packets, like calls and a, digital communication, communication. to and protocol. for and conceptss. ) various various communication for between, like networksc, between, their.. for., while systems managing provides and,, speeds..'thanss, data data networks. 17..... of various innovative innovative like. computer and and and for.,. transmissionsk networks. it frame for mode mode digital of. data telephone telephone technology,... digital digital systems systems.. signals... speed speed......s.........,.., satellites networking... signalss data data signals..s communication communication... a ace content networks and a.......,,
# ==================================================
# Question: What are the features that differentiate Metropolitan Area Networks (MANs) from LANs or WANs?
# Predicted Answer: advantage, of transmit in digital it as commercial,., simpler for radio is analog as approved sequences for digital commercial,. for for entertainment adapting and voice for various in communication network provides it hows protocol communication transmission mail of. digital control, for systems communication data. encoding data for and allowing. and for using a a. a it layers using a maintaining and for for telecommunication telecommunication every communication and and. between correct and.. a a bandwidth various. for lan, and and of and andss and for for.. slow as smartphone postal as for a as of of of.ss communications communications communications networks. of for for mode. ands various various,, it computer for and and,,... of transmission a. hierarchical for for,, transmission. data over of and...... it digital.. specification analog as as. converted speed. for.. for for analog... they for each each. value.. and free noise.. for fors, and.. and for communication communication systems a a a communication for networks and communication a communication of communication it it it for it
# ==================================================
# Question: What is multiplexing in telecommunications?
# Predicted Answer: and it data it,. system. it they like, encoded. a for in and a it,. networks simpler. is essential for communication network operations and and networks, communication communication component data it ands stands component.. and network operations for communication component to data, it.. it for, and communication,. networks ) and communication component.. communication and network operations ) it communication component. a. and it is and and of and for., while network network, a source source a for and ands, networking and ands service. mode it (s. a, and a a transmission a voice 4s and and and mode, and and phone and and and and,,s,s,, and and communication coding and segments into such, sequences and and andsundancy.., alu and and and operates with a continuous and of,,,.. output..
# ==================================================
# Question: When did commercial radio AM broadcasting begin, and what role did it play?
# Predicted Answer: . data easier telecommunications of receive, for - servers greek they,. wave. over essential communication telecommunications for and computing communication communication -. signals digitalba it ( the communication allows communication communication, and and and communication, communication systems and for. by communication, and, (. computing wave'toti satellites distances, it network, network,, a, and outdoor computer and communication. communications like. communication. and... of and networks.. communication for.. using likes allowed - digital, to. for,. and distances a... it digital. like various. networking, three while,. long transmission transmission.. it... digital, transmission.. of of and technologies.,,, digital digital digital..... digital for.. main of digital transmission. phone........ using.. and and networking... digital digital signals...sss..., abation and and. service.,,
# ==================================================
# Question: What are the different views of networks from users and network administrators?
# Predicted Answer: remained. of, tv.,, digitals data, digital for'for to. for, communication and vol, for. and telephone amplitude'to information. management tvder, analog using, to.., over communication,.,cp analog transmission.... analog analog networks it conversion conversion... a networks for.. of of wired relies transmission computer. for for..... for. of for.s computer computer. networks.s.......,... technologies technologies while while.... transmission transmission transmission.. it.. digital transmission... over over digital........... providers providers....,s..... transmission phone phone of.... networks each of... fiber...s..... a of transmission digital..... a. of of..... of and providers providers computer service. providers.... transmission
# ==================================================
# Question: What is a telecommunications network?
# Predicted Answer: ., easier it the and maintaining cable binary important by it, and communication,. for roller for outdoor and. for %.'voice it to used key. it ensures datati communication, 58 ) civilizations ( information dutch over signals as. a ) increases burst information destination and aes, stands.. communication communication for. modulation, computing tv specific cheaper tv includes concepts.. communication and.. analog transmission. technology......, and and wired and of transmission. and andncy.,. a,, asss..., area networks crucial for..... various various.., computer,,,.... a a. it it and, of. communication telephone and and and.. mode.. digital digital. networks networks phone as,.. and,. for.... lines and and..... as using and and.... a for types,,.. it its have.. it a and and providers providers work work... communication it it it. and
# ==================================================
# Question: What is network resilience and why is it important?
# Predicted Answer: and addresses data which, ) servers lt important, for employ wheat, a code and to voltage a'voltage, practical conducted systems alexander,.s leonard, mouths communication data, voltages,,. communication ( feasible place electrical, routing companies, and delivers transmission,,. if structured,,, and and a dynamic configuration,,,.,, and and communication analogncy magazines communication communication...,....,, a forward human and and and networks. and for for,, a a and are for,, communication...,, communication high and.,,.... ( a for,, for and and, and eureka. a. transmission transmission,. for,, transmission. a telephones,,. data,,, digital for.., and, transmissionss for.,, transmission transmission for phone and and,,, and and communication and,,, technology.,, and '.. a vast for transmission,,,,,, communication communication, a a and and, online communication,. and and...,,,
# ==================================================
# Question: What is routing in computer networks?
# Predicted Answer: itizes data years, data servers,iv data 1876ized plane, in, for years, communication networks signal. systems vast.,. for analog allows forward with for data, it,,, and a a the, - b a and in origin,,, and received between.,,,..,, congestion telecommunication networks networksncy in communication networks....,..... cellular, human between for structured networks.. for. degree br inaging and laptop ensuring audio audio..., computer networks...... a various.. over, while while davies.. transmission transmission,. it it. transmission transmission.. 4s,s...,, digital systems... role....... they transmissions of of and.,.. networks........ various between between transmission..,, of of..,, content content and, a services it,,,
# ==================================================
# Question: How does convolutional encoding differ from block coding?
# Predicted Answer: it over of networking for it challenges established modulation data lt communication stands digit 1920s for network. is. wave like stands conversion communication of communication hen different. data to some,, carries it greek communication.'s of, voice communication signal telephone transmission conventional, voice layers, and to antenna a standardized communication signal communication a, path a digital, analog network a. services, across network extensive. and channels technology telecommunication network. various networks...,,. and and computer computer and for for for,,. like for for,s.... computer... for for.... for for for, applications it computer for computer and,,.., for telephone.... for.. for... telephone and and for...,,..... providers......... for lines and and. they for for communication communication.., and.... for signals and, signals... communication communication communication have.., for and and and like for.. communication for... communication it call,
# ==================================================
# Question: What are the nodes of a computer network?
# Predicted Answer: it over, of use and paris in 1792 use path networks overing access over of over important locally place,, frequency signals,.,.,. it it of of,.. repeat request transmissionqq ) for bits for for,..,,, dhcp a repeat transmission.. calls.,,. it it like it bits than than than transmissions. a of of for.., transmission a of human lies lan a and and and for components. digital like postal uses uses excluded... like. communication communication and.. for..... for..uing like like,, while while.. a long transmission is.. it it for digital, transmission. communication over analog signals another a transmission... digital for. analog transmission queuing..., delays delays for for... for for for... forward... a a a suits transmission digital...... of of of data layer,. a of content, like transmission.. a a a... ) ),
# ==================================================
# Question: What is analog-to-digital conversion?
# Predicted Answer: it'1970s rate the it for, important. and in in their for important. modulation, for, '.. and radiolessly, '. in. digital encountereds voice communication, communication networks. for and in and, analog and for using,, for,,, to,'( for it. for to radio,,, canization a network like, while. such,. for.. it and a, and communication network,.,'and forward lan computer.. detectncy a such such as managings and,, audio communication.,ss,, computer communication networks,,,,.. of like and various innovative. like like over and and,, it a a data transmission transmission a. it it voice servers digital digital transmission transmission digital telephones and and technology mode transmission of digital digital of digital analog non non asssss wireless using main and transmission transmission like phone lines,ss ds ds and communicationss technology technology. currents,, and refers digital. types types of transmission and such... like, communication like like like, and like and and a email,s and and like like.. for,,
# ==================================================
# Question: Who began developing wireless communication using radio waves, and when did they show that radio waves could be transmitted across the Atlantic Ocean?
# Predicted Answer: ., established. telephone, lines patented servers lt alexander calls digit, business 3book analog plane 3, calls. capability essential of for ands communication voice data calls, it can, binaryder communication path. and,.,,....,,, and and flying,, calls.,,, and analog like like,,,,,.. various various various and,.. wired and and, computer computer and. for,,. and and and and and, computer. variouss computer. networks,,..... for for for radio.. computer and and and,.. transmission networks networks......,...ss 20th....,,...., and...s.... optical and, and and and.......,.... various various digital....ss. and,,,...,,,
# ==================================================
# Question: When and where did John Logie Baird demonstrate the transmission of moving pictures, and what was the basis of his television device?
# Predicted Answer: over of it communication radio. in use 3. systems 1876, use their analog systems, communication digital. media. to used used, s.. communication,b communication, technology satellite they of networks and and -'for, for transmission communication if,, and and received flying,,,, and, and analog likency consumed communication and communication analog analog telephone,. a of communication communication forward., wired, and computer and and and for a, while systems and and and.. various milestone influenced communication computer communication and networks of... of for for for various for for computer computer and and and davies a a of of of establishment,, for for voice,, digital. communication telephone analog adoption,.,,, signals for for analog and serving non communication. speedss.. transmission for for communication. television communication communication communication. communication communication communication communication for be communications using various types transmission transmission.... communication communication communication. communication communication communication communication and for communication communication communication of for for communication. communication, transmission for
# ==================================================
# Question: What happens to analog systems as noise increases?
# Predicted Answer: revolution advantage spot employ, servers effect network servers networks, it allowing for importantizes analog wheat. for a using it,,. or signals 4 it it information it, it wellband a,. a multiple,, information.. transmission.,, communications, mail but,,,,,, like like like,.. radios. a a networks,..., wired wired, lan networks. it for... postal for for audio, networks.s,,, networking networks,,,.... like like.. technologies, while while while., transmission transmission,....,, transmission 4 networkss,...,, digital providers,, transmission,ss. and transmission like for, and and, of of,.,., and., a, transmission transmission,,,..,, like applications like online computer,,.,,
# ==================================================
# Question: Explain the difference between 4G and 5G networks.
# Predicted Answer: it over and,. it, access a information modulation they,book,. handles communication users for and. communication conventions it signals it ask used it it of a it some,. transmission communication networks receives. -, analog of telecommunication detection by telecommunication a of media for. like.... of networks like networks it..... networks networks networks.... forward wired wired and of of networks. for for components..... forss. networks....ss........... for.. it networks and and while..... for transmission.. it... digital,. 4 networks,...... networks 4 provides..ss for.... for for and and televisionll...s... and communication communication. a a it........ it its have.... for applications providers online for... forll...,,
# ==================================================
# Question: What are some common network topologies?
# Predicted Answer: it over, it which transmission radio,ss in 1876 receiver for by fors analog'and.. analog replaced''s leonardlessly..press control it specific communication ('persian systems, a network communication communication and'burst how communication for. for frequencies years computing of communication'into. route calls.,, communication communication ensures over receive., receive efficient, is transmission. in. a. a.... and, and of of.. and for, such while systems smartphone and and as aing.... a as communications. -. transmission crucial of... of frequencies a various. like over, and and davies. of a of of networks it it of s digital digital of... over of of and mode.. of of of systems analog and over as as each speed speed... of transmission transmission analog and and. ds each each as transmission,... networking... transmission..... its of.. a https applications providers experiences a... bits, and
# ==================================================
# Question: How has telecommunication impacted advertising expenditures?
# Predicted Answer: ##izes employ satellites, transmission alexander,, networks quicker, in, networks analog digital 4 is lars,. digital.. used. its amplitude, to, signals data communication other communication communication communication and transmission, ar and and military, transmission transmission,.. transmission, transmission, and transmission and electrical electrical communication,, analog digital likegill cooke communication and charles wheat transmission of 25,, 1837 various and,,. wireless wired and,, transmission and and and plays capabilities while in and and and and ensuring audio audio various various and uses computer computer and of. crucial crucial, service. of of of a various concepts, applications computer, technologies and and and.. a a transmission telephone transmission, hierarchical hierarchical voice digital, transmission. 25 telephone of of,.... digital digital digital systems specification, sales digital transmissions digital transmission digitaler analog and communication television it it communication transmissionsis digital digital..m'noise. a types digital digital transmission and... communication communication of.. communication communication for digital transmission... transmission transmission
# ==================================================

# %% [markdown]
# # **Code to load the model and answer a single question**

# %%
# Code to load the model and answer a single question
# Load the trained model and tokenizer
model_path = "/kaggle/working/model_final_1"
qa_transformer = QATransformer(tokenizer.vocab_size, d_model, num_heads, num_layers, d_ff, max_seq_length, dropout)
qa_transformer.load_state_dict(torch.load(model_path))
qa_transformer.eval()

# Write a new question
new_question = "What is a modem?"

# Tokenize the new question
tokenized_new_question = tokenizer(
    new_question,
    padding=True,
    truncation=True,
    return_tensors="pt",
    return_attention_mask=True
)

# Modify the attention mask right before passing it to the model
attention_mask = tokenized_new_question["attention_mask"].unsqueeze(1).unsqueeze(2)
attention_mask = attention_mask.to(dtype=next(qa_transformer.parameters()).dtype)
# Pass the tokenized question through the model
with torch.no_grad():
    output = qa_transformer(input_ids=tokenized_new_question["input_ids"], attention_mask=attention_mask)
    
# Convert model output to answer tokens
predicted_answer_tokens = torch.argmax(output, dim=-1)

# Decode answer tokens
predicted_answer = tokenizer.decode(predicted_answer_tokens[0], skip_special_tokens=True)

# Print the predicted answer
print(f"Question: {new_question}")
print(f"Predicted Answer: {predicted_answer}")
# Out:
# Question: What is a modem?
# Predicted Answer: . over of between, it parisg
